# %%
# Install Dependencies

# !pip uninstall -y numpy
# !pip install --force-reinstall numpy==1.26.4

# !pip install torch==2.2.1 torchvision==0.17.1 torchaudio==2.2.1 sentence-transformers==2.2.2
# !pip install pandas==2.0.0
# !pip install transformers==4.41.0 scikit-learn==1.2.0
# !pip install huggingface-hub==0.25.2
# !pip install nltk==3.8.1 rouge-score==0.1.2 bert-score==0.3.13 -q
# !pip install tqdm==4.66.5 -q
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 96.5 MB/s eta 0:00:00
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# Collecting torch==2.2.1
#   Downloading torch-2.2.1-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision==0.17.1
#   Downloading torchvision-0.17.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting torchaudio==2.2.1
#   Downloading torchaudio-2.2.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting sentence-transformers==2.2.2
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (4.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.1)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch==2.2.1)
#   Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.17.1) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.17.1) (11.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==2.2.2) (4.50.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==2.2.2) (4.67.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==2.2.2) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==2.2.2) (1.14.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==2.2.2) (3.9.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==2.2.2) (0.2.0)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==2.2.2) (0.30.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1) (12.5.82)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.32.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.2.1) (3.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->sentence-transformers==2.2.2) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->sentence-transformers==2.2.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers==2.2.2) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.2.1) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2025.1.31)
# Downloading torch-2.2.1-cp311-cp311-manylinux1_x86_64.whl (755.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 2.0 MB/s eta 0:00:00
# Downloading torchvision-0.17.1-cp311-cp311-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 70.5 MB/s eta 0:00:00
# Downloading torchaudio-2.2.1-cp311-cp311-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 78.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 99.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 88.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 53.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 18.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 35.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 18.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 12.8 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.4 MB/s eta 0:00:00
# Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 6.8 MB/s eta 0:00:00
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=f71fb23a4b2ad117318b9105eec23fc01db1c33a118290ec8b4fec9cb491cd85
#   Stored in directory: /root/.cache/pip/wheels/ff/27/bf/ffba8b318b02d7f691a57084ee154e26ed24d012b0c7805881
# Successfully built sentence-transformers
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, torchvision, torchaudio, sentence-transformers
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.6.0+cu124
#     Uninstalling torchaudio-2.6.0+cu124:
#       Successfully uninstalled torchaudio-2.6.0+cu124
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.4.1
#     Uninstalling sentence-transformers-3.4.1:
#       Successfully uninstalled sentence-transformers-3.4.1
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvtx-cu12-12.1.105 sentence-transformers-2.2.2 torch-2.2.1 torchaudio-2.2.1 torchvision-0.17.1 triton-2.2.0
# Collecting pandas==2.0.0
#   Downloading pandas-2.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.0.0) (2025.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from pandas==2.0.0) (1.26.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.0) (1.17.0)
# Downloading pandas-2.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 95.8 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.0.0 which is incompatible.
# mizani 0.13.2 requires pandas>=2.2.0, but you have pandas 2.0.0 which is incompatible.
# xarray 2025.1.2 requires pandas>=2.1, but you have pandas 2.0.0 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.0.0 which is incompatible.
# Successfully installed pandas-2.0.0
# Collecting transformers==4.41.0
#   Downloading transformers-4.41.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.0 MB/s eta 0:00:00
# Collecting scikit-learn==1.2.0
#   Downloading scikit_learn-1.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (0.30.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (2.32.3)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.41.0)
#   Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (4.67.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.2.0) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.2.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.2.0) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.0) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.0) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.0) (2025.1.31)
# Downloading transformers-4.41.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 57.7 MB/s eta 0:00:00
# Downloading scikit_learn-1.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 82.5 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 73.2 MB/s eta 0:00:00
# Installing collected packages: scikit-learn, tokenizers, transformers
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.50.3
#     Uninstalling transformers-4.50.3:
#       Successfully uninstalled transformers-4.50.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.0 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.0 which is incompatible.
# Successfully installed scikit-learn-1.2.0 tokenizers-0.19.1 transformers-4.41.0
# Collecting huggingface-hub==0.25.2
#   Downloading huggingface_hub-0.25.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.25.2) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.25.2) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.25.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.25.2) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.25.2) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.25.2) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.25.2) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.25.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.25.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.25.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.25.2) (2025.1.31)
# Downloading huggingface_hub-0.25.2-py3-none-any.whl (436 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.6/436.6 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.30.1
#     Uninstalling huggingface-hub-0.30.1:
#       Successfully uninstalled huggingface-hub-0.30.1
# Successfully installed huggingface-hub-0.25.2
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.5 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# textblob 0.19.0 requires nltk>=3.9, but you have nltk 3.8.1 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 3.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# textblob 0.19.0 requires nltk>=3.9, but you have nltk 3.8.1 which is incompatible.

# %%
# Setup and Imports

import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import (
    BartForConditionalGeneration, BartTokenizer,
    DPRContextEncoder, DPRQuestionEncoder,
    DPRContextEncoderTokenizer, DPRQuestionEncoderTokenizer
)
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
import os
from google.colab import drive
from tqdm import tqdm
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer
from bert_score import score as bert_score
import string
import nltk
import json
import pickle

nltk.download('wordnet')
nltk.download('punkt')

# Mount Google Drive
drive.mount('/content/drive')

# Configuration
class Config:
    BASE_PATH = "/content/drive/MyDrive/LJMU-Datasets"
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    BART_MODEL_NAME = "facebook/bart-base"
    DPR_CTX_MODEL_NAME = "facebook/dpr-ctx_encoder-single-nq-base"
    DPR_QUESTION_MODEL_NAME = "facebook/dpr-question_encoder-single-nq-base"
    BATCH_SIZE = 8
    MAX_EPOCHS = 3
    NUM_WORKERS = 4
    MAX_LENGTH = 256
    SUBSET_SIZE = 500
    HOTPOTQA_MAX_SAMPLES = 1000
    WIKIDATA_SUBSET_SIZE = 30000

CONFIG = Config()
print(f"Using device: {CONFIG.DEVICE}")

# Clear GPU memory
torch.cuda.empty_cache()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Mounted at /content/drive
# Using device: cuda

# %%
# Load Artifacts from Step 2 and Create DataLoaders

import pickle

save_path = '/content/drive/MyDrive/bert_retrieval_artifacts_v4'

# Load raw datasets
qa_train_path_v4 = os.path.join(CONFIG.BASE_PATH, "qa_train_v4.csv")
qa_val_path_v4 = os.path.join(CONFIG.BASE_PATH, "qa_val_v4.csv")
triple_train_path_v4 = os.path.join(CONFIG.BASE_PATH, "triple_train_v4.csv")

qa_train_df_v4 = pd.read_csv(qa_train_path_v4)
qa_val_df_v4 = pd.read_csv(qa_val_path_v4)
triple_train_df_v4 = pd.read_csv(triple_train_path_v4)

# Split triple_train_df into train and validation sets (80/20)
triple_train_df_v4, triple_val_df_v4 = train_test_split(triple_train_df_v4, train_size=0.8, random_state=42)
print(f"Triple Train Size (Version 4): {len(triple_train_df_v4)}, Triple Val Size (Version 4): {len(triple_val_df_v4)}")

# Load all_candidates
with open(os.path.join(save_path, 'all_candidates_v4.pkl'), 'rb') as f:
    all_candidates = pickle.load(f)

# Define RetrievalDataset class
class RetrievalDataset(Dataset):
    def __init__(self, df: pd.DataFrame, bart_tokenizer: BartTokenizer, dpr_question_tokenizer: DPRQuestionEncoderTokenizer,
                 max_length: int = 256, task: str = "qa", candidate_objects: list = None):
        self.bart_tokenizer = bart_tokenizer
        self.dpr_question_tokenizer = dpr_question_tokenizer
        self.max_length = max_length
        self.task = task
        self.data = df
        self.candidate_objects = candidate_objects

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        question = row["question"]
        context = row["context"]
        answer = row["answer"]

        if self.task == "qa":
            bart_input_text = f"question: {question} context: {context}"
        else:
            bart_input_text = f"complete the triple with the exact object: {question} context: {context}"
        bart_inputs = self.bart_tokenizer(
            bart_input_text,
            return_tensors="pt",
            max_length=self.max_length,
            truncation=True,
            padding="max_length"
        )
        bart_labels = self.bart_tokenizer(
            answer,
            return_tensors="pt",
            max_length=self.max_length,
            truncation=True,
            padding="max_length"
        )

        dpr_inputs = self.dpr_question_tokenizer(
            question,
            return_tensors="pt",
            max_length=self.max_length,
            truncation=True,
            padding="max_length"
        )

        item = {
            "task": self.task,
            "bart_input_ids": bart_inputs["input_ids"].squeeze().long(),  # Ensure LongTensor
            "bart_attention_mask": bart_inputs["attention_mask"].squeeze().long(),
            "bart_labels": bart_labels["input_ids"].squeeze().long(),
            "dpr_input_ids": dpr_inputs["input_ids"].squeeze().long(),  # Ensure LongTensor
            "dpr_attention_mask": dpr_inputs["attention_mask"].squeeze().long(),
            "question": question,
            "answer": answer
        }

        if self.task == "triple" and self.candidate_objects:
            label_idx = self.candidate_objects.index(answer) if answer in self.candidate_objects else -1
            item["label_idx"] = label_idx

        return item

# Create DataLoaders from raw data
bart_tokenizer = BartTokenizer.from_pretrained(CONFIG.BART_MODEL_NAME)
dpr_question_tokenizer = DPRQuestionEncoderTokenizer.from_pretrained(CONFIG.DPR_QUESTION_MODEL_NAME)

qa_train_dataset_v4 = RetrievalDataset(qa_train_df_v4, bart_tokenizer, dpr_question_tokenizer, task="qa", candidate_objects=all_candidates)
qa_val_dataset_v4 = RetrievalDataset(qa_val_df_v4, bart_tokenizer, dpr_question_tokenizer, task="qa", candidate_objects=all_candidates)
triple_train_dataset_v4 = RetrievalDataset(triple_train_df_v4, bart_tokenizer, dpr_question_tokenizer, task="triple", candidate_objects=all_candidates)
triple_val_dataset_v4 = RetrievalDataset(triple_val_df_v4, bart_tokenizer, dpr_question_tokenizer, task="triple", candidate_objects=all_candidates)

qa_train_loader_v4 = DataLoader(qa_train_dataset_v4, batch_size=CONFIG.BATCH_SIZE, shuffle=True, num_workers=CONFIG.NUM_WORKERS)
qa_val_loader_v4 = DataLoader(qa_val_dataset_v4, batch_size=CONFIG.BATCH_SIZE, shuffle=False, num_workers=CONFIG.NUM_WORKERS)
triple_train_loader_v4 = DataLoader(triple_train_dataset_v4, batch_size=CONFIG.BATCH_SIZE, shuffle=True, num_workers=CONFIG.NUM_WORKERS)
triple_val_loader_v4 = DataLoader(triple_val_dataset_v4, batch_size=CONFIG.BATCH_SIZE, shuffle=False, num_workers=CONFIG.NUM_WORKERS)

print(f"Created QA DataLoaders (Version 4): QA Train={len(qa_train_dataset_v4)}, QA Val={len(qa_val_dataset_v4)}")
print(f"Created Triple DataLoaders (Version 4): Triple Train={len(triple_train_dataset_v4)}, Triple Val={len(triple_val_dataset_v4)}")

# Load BART models and tokenizer
bart_qa_model = BartForConditionalGeneration.from_pretrained(CONFIG.BART_MODEL_NAME).to(CONFIG.DEVICE)
bart_qa_model.load_state_dict(torch.load(os.path.join(save_path, 'bart_qa_v4.pt')))
bart_tokenizer = BartTokenizer.from_pretrained(CONFIG.BART_MODEL_NAME)
bart_qa_model.eval()

# Load DPR models and tokenizers (post-fine-tuning from Step 2)
ctx_encoder_qa = DPRContextEncoder.from_pretrained(os.path.join(CONFIG.BASE_PATH, "dpr_ctx_encoder_qa_v4")).to(CONFIG.DEVICE)
question_encoder_qa = DPRQuestionEncoder.from_pretrained(os.path.join(CONFIG.BASE_PATH, "dpr_question_encoder_qa_v4")).to(CONFIG.DEVICE)
ctx_encoder_triple = DPRContextEncoder.from_pretrained(os.path.join(CONFIG.BASE_PATH, "dpr_ctx_encoder_triple_v4")).to(CONFIG.DEVICE)
question_encoder_triple = DPRQuestionEncoder.from_pretrained(os.path.join(CONFIG.BASE_PATH, "dpr_question_encoder_triple_v4")).to(CONFIG.DEVICE)
ctx_tokenizer = DPRContextEncoderTokenizer.from_pretrained(CONFIG.DPR_CTX_MODEL_NAME)
question_tokenizer = DPRQuestionEncoderTokenizer.from_pretrained(CONFIG.DPR_QUESTION_MODEL_NAME)
candidate_embeddings_qa = torch.load(os.path.join(save_path, 'dpr_candidate_embeddings_v4.pt')).to(CONFIG.DEVICE)
candidate_embeddings_triple = torch.load(os.path.join(save_path, 'dpr_candidate_embeddings_triple_v4.pt')).to(CONFIG.DEVICE)

# Load sentence transformer
sentence_transformer = SentenceTransformer('all-MiniLM-L6-v2')

print("Artifacts loaded from Step 2 and DataLoaders rebuilt for Version 4.")
# Out:
# Triple Train Size (Version 4): 20908, Triple Val Size (Version 4): 5227
# Created QA DataLoaders (Version 4): QA Train=294, QA Val=27
# Created Triple DataLoaders (Version 4): Triple Train=20908, Triple Val=5227
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'DPRQuestionEncoderTokenizer'.
# The class this function is called from is 'DPRContextEncoderTokenizer'.
# Artifacts loaded from Step 2 and DataLoaders rebuilt for Version 4.

# %%
# Define Helper Functions

# Normalize text for evaluation
def normalize_text(text: str) -> str:
    text = str(text).lower().strip()
    text = text.translate(str.maketrans("", "", string.punctuation))
    articles = {'a', 'an', 'the'}
    words = text.split()
    words = [word for word in words if word not in articles]
    return ' '.join(words)

# Compute BLEU score
def compute_bleu(generated: str, reference: str) -> float:
    return sentence_bleu([reference.split()], generated.split())

# Compute ROUGE-L score
def compute_rouge_l(generated: str, reference: str) -> float:
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    return scorer.score(reference, generated)['rougeL'].fmeasure

# Compute BERTScore
def compute_bertscore(generated: str, reference: str) -> float:
    return bert_score([generated], [reference], lang="en", verbose=False)[2].mean().item()

# Compute MRR for RL reward
def compute_mrr(generated_ranking: torch.Tensor, ref_idx: int) -> float:
    rank = (generated_ranking == ref_idx).nonzero(as_tuple=True)[0].item() + 1 if ref_idx in generated_ranking else len(generated_ranking)
    return 1.0 / rank

print("Helper functions defined.")
# Out:
# Helper functions defined.

# %%
# Define RL Helper Functions

# Normalize text for evaluation
def normalize_text(text: str) -> str:
    text = str(text).lower().strip()
    text = text.translate(str.maketrans("", "", string.punctuation))
    articles = {'a', 'an', 'the'}
    words = text.split()
    words = [word for word in words if word not in articles]
    return ' '.join(words)

# Compute BLEU score
def compute_bleu(generated: str, reference: str) -> float:
    return sentence_bleu([reference.split()], generated.split())

# Compute ROUGE-L score
def compute_rouge_l(generated: str, reference: str) -> float:
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    return scorer.score(reference, generated)['rougeL'].fmeasure

# Compute BERTScore
def compute_bertscore(generated: str, reference: str) -> float:
    return bert_score.score([generated], [reference], lang="en", verbose=False)[2].mean().item()

# Compute MRR for reward
def compute_mrr(generated_ranking: torch.Tensor, ref_idx: int) -> float:
    rank = (generated_ranking == ref_idx).nonzero(as_tuple=True)[0].item() + 1 if ref_idx in generated_ranking else len(generated_ranking)
    return 1.0 / rank

# Compute reward for RL
def compute_reward(generated_ranking: torch.Tensor, reference: str) -> float:
    candidates = all_candidates[:100]  # Use small candidate pool for efficiency
    ref_idx = candidates.index(reference) if reference in candidates else -1
    if ref_idx == -1:
        return 0.0
    mrr = compute_mrr(generated_ranking, ref_idx)
    exact_match_bonus = 0.5 if generated_ranking[0] == ref_idx else 0.0
    return mrr + exact_match_bonus

# Policy Network for DPR (simple MLP to adjust embeddings)
class PolicyNetwork(torch.nn.Module):
    def __init__(self, input_dim=768, hidden_dim=256):
        super(PolicyNetwork, self).__init__()
        self.network = torch.nn.Sequential(
            torch.nn.Linear(input_dim, hidden_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_dim, input_dim),
            torch.nn.Tanh()  # Output adjustment to [-1, 1]
        )

    def forward(self, x):
        return self.network(x)

# RL Environment for DPR ranking
class RankingEnvironment:
    def __init__(self, ctx_encoder, question_encoder, candidates, candidate_embeddings, val_loader, task: str = "qa"):
        self.ctx_encoder = ctx_encoder
        self.question_encoder = question_encoder
        self.candidates = candidates
        self.candidate_embeddings = candidate_embeddings
        self.val_loader = val_loader
        self.task = task
        self.current_batch = None
        self.current_idx = 0
        self.batch_iterator = iter(val_loader)

    def reset(self):
        try:
            self.current_batch = next(self.batch_iterator)
            self.current_idx = 0
        except StopIteration:
            self.batch_iterator = iter(self.val_loader)
            self.current_batch = next(self.batch_iterator)
            self.current_idx = 0
        question_inputs = {
            "input_ids": self.current_batch["dpr_input_ids"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0),
            "attention_mask": self.current_batch["dpr_attention_mask"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0)
        }
        with torch.no_grad():
            state = self.question_encoder(**question_inputs).pooler_output  # Shape: (1, 768)
        return state

    def step(self, action):
        question_inputs = {
            "input_ids": self.current_batch["dpr_input_ids"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0),
            "attention_mask": self.current_batch["dpr_attention_mask"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0)
        }
        with torch.no_grad():
            question_embedding = self.question_encoder(**question_inputs).pooler_output  # Shape: (1, 768)
        adjusted_embedding = question_embedding + action  # Adjust embedding
        similarities = torch.matmul(adjusted_embedding, self.candidate_embeddings.T)  # Shape: (1, num_candidates)
        rankings = torch.argsort(similarities, dim=1, descending=True)
        ref = self.current_batch["answer"][self.current_idx]
        done = False
        if ref not in self.candidates:
            reward = 0.0
            done = True
        else:
            reward = compute_reward(rankings[0].cpu(), ref)
            print(f"Task: {self.task}, Reward: {reward:.4f}")

        # Move to next sample
        self.current_idx += 1
        if self.current_idx >= len(self.current_batch["answer"]):
            try:
                self.current_batch = next(self.batch_iterator)
                self.current_idx = 0
            except StopIteration:
                done = True

        # Get next state
        if not done:
            next_question_inputs = {
                "input_ids": self.current_batch["dpr_input_ids"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0),
                "attention_mask": self.current_batch["dpr_attention_mask"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0)
            }
            with torch.no_grad():
                next_state = self.question_encoder(**next_question_inputs).pooler_output
        else:
            next_state = None

        return next_state, reward, done

# PPO Implementation
def compute_gae(rewards, values, next_value, gamma=0.99, lam=0.95):
    advantages = []
    gae = 0
    rewards = rewards + [next_value]
    values = values + [next_value]
    for t in reversed(range(len(rewards) - 1)):
        delta = rewards[t] + gamma * values[t + 1] - values[t]
        gae = delta + gamma * lam * gae
        advantages.insert(0, gae)
    return advantages

def ppo_update(policy, optimizer, states, actions, old_log_probs, advantages, returns, clip_epsilon=0.1, epochs=5):
    for _ in range(epochs):
        policy.train()
        new_log_probs = []
        for state, action in zip(states, actions):
            state = state.to(CONFIG.DEVICE)
            action = action.to(CONFIG.DEVICE)
            adjustment = policy(state)
            dist = torch.distributions.Normal(adjustment, 0.1)
            log_prob = dist.log_prob(action).sum(dim=-1)
            new_log_probs.append(log_prob)
        new_log_probs = torch.stack(new_log_probs)

        # Compute ratio
        ratios = torch.exp(new_log_probs - torch.stack(old_log_probs))

        # Compute surrogate loss
        surr1 = ratios * torch.tensor(advantages, device=CONFIG.DEVICE)
        surr2 = torch.clamp(ratios, 1 - clip_epsilon, 1 + clip_epsilon) * torch.tensor(advantages, device=CONFIG.DEVICE)
        policy_loss = -torch.min(surr1, surr2).mean()

        # Update policy
        optimizer.zero_grad()
        policy_loss.backward()
        optimizer.step()
        print(f"Policy Loss: {policy_loss.item():.4f}")

    return policy_loss.item()

print("RL helper functions defined.")
# Out:
# RL helper functions defined.

# %%
# RL Fine-Tuning for DPR on QA Task

# Fine-tune DPR with PPO on QA data
policy_qa = PolicyNetwork(input_dim=768, hidden_dim=256).to(CONFIG.DEVICE)
value_network_qa = PolicyNetwork(input_dim=768, hidden_dim=256).to(CONFIG.DEVICE)
policy_optimizer_qa = torch.optim.Adam(policy_qa.parameters(), lr=5e-5)
value_optimizer_qa = torch.optim.Adam(value_network_qa.parameters(), lr=5e-5)

# Create environment for QA task
qa_env = RankingEnvironment(ctx_encoder_qa, question_encoder_qa, all_candidates, candidate_embeddings_qa, qa_val_loader_v4, task="qa")

num_episodes = 500  # Reduced number of episodes
max_steps_per_episode = 50  # Maximum steps per episode

print("Fine-tuning DPR with PPO on QA data...")
for episode in range(num_episodes):
    print(f"QA Episode {episode + 1}/{num_episodes}")
    state = qa_env.reset()
    if state.dim() == 1:
        state = state.unsqueeze(0)
    states, actions, rewards, old_log_probs, values = [], [], [], [], []
    done = False
    episode_steps = 0

    while not done and episode_steps < max_steps_per_episode:
        state = state.to(CONFIG.DEVICE)
        with torch.no_grad():
            adjustment = policy_qa(state)
            dist = torch.distributions.Normal(adjustment, 0.1)
            action = dist.sample()
            log_prob = dist.log_prob(action).sum(dim=-1)
            value = value_network_qa(state).mean()

        next_state, reward, done = qa_env.step(action)

        if next_state is not None and next_state.dim() == 1:
            next_state = next_state.unsqueeze(0)

        states.append(state)
        actions.append(action)
        rewards.append(reward)
        old_log_probs.append(log_prob)
        values.append(value.item())

        state = next_state
        episode_steps += 1

    # Compute returns and advantages
    with torch.no_grad():
        next_value = value_network_qa(state).mean().item() if state is not None else 0.0
    advantages = compute_gae(rewards, values, next_value)
    returns = [r + next_value for r in rewards]

    # Update policy and value network
    policy_loss = ppo_update(policy_qa, policy_optimizer_qa, states, actions, old_log_probs, advantages, returns)

    # Update value network
    value_loss = 0
    for state, ret in zip(states, returns):
        state = state.to(CONFIG.DEVICE)
        value = value_network_qa(state).mean()
        value_loss += (value - ret) ** 2
    value_loss = value_loss / len(states)
    value_optimizer_qa.zero_grad()
    value_loss.backward()
    value_optimizer_qa.step()
    print(f"QA Value Loss: {value_loss.item():.4f}")

# Save fine-tuned DPR models for QA task (Version 4)
ctx_encoder_qa.save_pretrained(os.path.join(CONFIG.BASE_PATH, "dpr_ctx_encoder_rl_qa_v4"))
question_encoder_qa.save_pretrained(os.path.join(CONFIG.BASE_PATH, "dpr_question_encoder_rl_qa_v4"))
print("Saved RL fine-tuned DPR models for QA task.")
# Out:
# Streaming output truncated to the last 5000 lines.
# QA Value Loss: 0.0275
# QA Episode 354/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1257
# Policy Loss: -1.2374
# Policy Loss: -1.2356
# Policy Loss: -1.2326
# Policy Loss: -1.2277
# QA Value Loss: 0.0275
# QA Episode 355/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1257
# Policy Loss: -1.2375
# Policy Loss: -1.2359
# Policy Loss: -1.2332
# Policy Loss: -1.2290
# QA Value Loss: 0.0274
# QA Episode 356/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1256
# Policy Loss: -1.2374
# Policy Loss: -1.2357
# Policy Loss: -1.2329
# Policy Loss: -1.2283
# QA Value Loss: 0.0273
# QA Episode 357/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2372
# Policy Loss: -1.2354
# Policy Loss: -1.2323
# Policy Loss: -1.2270
# QA Value Loss: 0.0273
# QA Episode 358/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2371
# Policy Loss: -1.2353
# Policy Loss: -1.2322
# Policy Loss: -1.2273
# QA Value Loss: 0.0272
# QA Episode 359/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2369
# Policy Loss: -1.2349
# Policy Loss: -1.2313
# Policy Loss: -1.2251
# QA Value Loss: 0.0271
# QA Episode 360/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1252
# Policy Loss: -1.2368
# Policy Loss: -1.2350
# Policy Loss: -1.2317
# Policy Loss: -1.2262
# QA Value Loss: 0.0271
# QA Episode 361/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1252
# Policy Loss: -1.2368
# Policy Loss: -1.2349
# Policy Loss: -1.2315
# Policy Loss: -1.2256
# QA Value Loss: 0.0270
# QA Episode 362/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1251
# Policy Loss: -1.2368
# Policy Loss: -1.2351
# Policy Loss: -1.2321
# Policy Loss: -1.2275
# QA Value Loss: 0.0269
# QA Episode 363/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1251
# Policy Loss: -1.2367
# Policy Loss: -1.2349
# Policy Loss: -1.2318
# Policy Loss: -1.2269
# QA Value Loss: 0.0269
# QA Episode 364/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1251
# Policy Loss: -1.2367
# Policy Loss: -1.2350
# Policy Loss: -1.2320
# Policy Loss: -1.2273
# QA Value Loss: 0.0268
# QA Episode 365/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1251
# Policy Loss: -1.2367
# Policy Loss: -1.2348
# Policy Loss: -1.2315
# Policy Loss: -1.2259
# QA Value Loss: 0.0267
# QA Episode 366/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1251
# Policy Loss: -1.2367
# Policy Loss: -1.2348
# Policy Loss: -1.2315
# Policy Loss: -1.2260
# QA Value Loss: 0.0267
# QA Episode 367/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1251
# Policy Loss: -1.2367
# Policy Loss: -1.2347
# Policy Loss: -1.2313
# Policy Loss: -1.2257
# QA Value Loss: 0.0266
# QA Episode 368/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1251
# Policy Loss: -1.2368
# Policy Loss: -1.2353
# Policy Loss: -1.2329
# Policy Loss: -1.2291
# QA Value Loss: 0.0265
# QA Episode 369/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1251
# Policy Loss: -1.2368
# Policy Loss: -1.2349
# Policy Loss: -1.2316
# Policy Loss: -1.2263
# QA Value Loss: 0.0265
# QA Episode 370/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1252
# Policy Loss: -1.2367
# Policy Loss: -1.2344
# Policy Loss: -1.2301
# Policy Loss: -1.2226
# QA Value Loss: 0.0264
# QA Episode 371/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2369
# Policy Loss: -1.2349
# Policy Loss: -1.2314
# Policy Loss: -1.2254
# QA Value Loss: 0.0263
# QA Episode 372/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2370
# Policy Loss: -1.2353
# Policy Loss: -1.2324
# Policy Loss: -1.2278
# QA Value Loss: 0.0263
# QA Episode 373/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2357
# Policy Loss: -1.2333
# Policy Loss: -1.2295
# QA Value Loss: 0.0262
# QA Episode 374/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2370
# Policy Loss: -1.2349
# Policy Loss: -1.2311
# Policy Loss: -1.2245
# QA Value Loss: 0.0262
# QA Episode 375/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2359
# Policy Loss: -1.2337
# Policy Loss: -1.2304
# QA Value Loss: 0.0261
# QA Episode 376/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2371
# Policy Loss: -1.2354
# Policy Loss: -1.2324
# Policy Loss: -1.2275
# QA Value Loss: 0.0260
# QA Episode 377/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2370
# Policy Loss: -1.2351
# Policy Loss: -1.2315
# Policy Loss: -1.2254
# QA Value Loss: 0.0260
# QA Episode 378/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2371
# Policy Loss: -1.2353
# Policy Loss: -1.2321
# Policy Loss: -1.2269
# QA Value Loss: 0.0259
# QA Episode 379/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2371
# Policy Loss: -1.2355
# Policy Loss: -1.2328
# Policy Loss: -1.2284
# QA Value Loss: 0.0259
# QA Episode 380/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2370
# Policy Loss: -1.2353
# Policy Loss: -1.2320
# Policy Loss: -1.2264
# QA Value Loss: 0.0258
# QA Episode 381/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2371
# Policy Loss: -1.2357
# Policy Loss: -1.2333
# Policy Loss: -1.2296
# QA Value Loss: 0.0258
# QA Episode 382/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2371
# Policy Loss: -1.2355
# Policy Loss: -1.2330
# Policy Loss: -1.2290
# QA Value Loss: 0.0257
# QA Episode 383/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2370
# Policy Loss: -1.2353
# Policy Loss: -1.2322
# Policy Loss: -1.2271
# QA Value Loss: 0.0256
# QA Episode 384/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2370
# Policy Loss: -1.2352
# Policy Loss: -1.2321
# Policy Loss: -1.2269
# QA Value Loss: 0.0256
# QA Episode 385/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2370
# Policy Loss: -1.2355
# Policy Loss: -1.2328
# Policy Loss: -1.2285
# QA Value Loss: 0.0255
# QA Episode 386/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2370
# Policy Loss: -1.2353
# Policy Loss: -1.2324
# Policy Loss: -1.2276
# QA Value Loss: 0.0255
# QA Episode 387/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2370
# Policy Loss: -1.2354
# Policy Loss: -1.2325
# Policy Loss: -1.2280
# QA Value Loss: 0.0254
# QA Episode 388/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2371
# Policy Loss: -1.2357
# Policy Loss: -1.2333
# Policy Loss: -1.2295
# QA Value Loss: 0.0254
# QA Episode 389/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2369
# Policy Loss: -1.2348
# Policy Loss: -1.2311
# Policy Loss: -1.2247
# QA Value Loss: 0.0253
# QA Episode 390/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2371
# Policy Loss: -1.2356
# Policy Loss: -1.2331
# Policy Loss: -1.2292
# QA Value Loss: 0.0253
# QA Episode 391/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2372
# Policy Loss: -1.2357
# Policy Loss: -1.2333
# Policy Loss: -1.2294
# QA Value Loss: 0.0252
# QA Episode 392/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2371
# Policy Loss: -1.2356
# Policy Loss: -1.2330
# Policy Loss: -1.2289
# QA Value Loss: 0.0252
# QA Episode 393/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2357
# Policy Loss: -1.2331
# Policy Loss: -1.2290
# QA Value Loss: 0.0251
# QA Episode 394/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2373
# Policy Loss: -1.2360
# Policy Loss: -1.2340
# Policy Loss: -1.2309
# QA Value Loss: 0.0251
# QA Episode 395/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2357
# Policy Loss: -1.2332
# Policy Loss: -1.2290
# QA Value Loss: 0.0250
# QA Episode 396/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2359
# Policy Loss: -1.2336
# Policy Loss: -1.2300
# QA Value Loss: 0.0250
# QA Episode 397/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2358
# Policy Loss: -1.2334
# Policy Loss: -1.2296
# QA Value Loss: 0.0249
# QA Episode 398/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2373
# Policy Loss: -1.2360
# Policy Loss: -1.2339
# Policy Loss: -1.2306
# QA Value Loss: 0.0249
# QA Episode 399/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2358
# Policy Loss: -1.2335
# Policy Loss: -1.2298
# QA Value Loss: 0.0248
# QA Episode 400/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2358
# Policy Loss: -1.2333
# Policy Loss: -1.2295
# QA Value Loss: 0.0248
# QA Episode 401/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2359
# Policy Loss: -1.2338
# Policy Loss: -1.2304
# QA Value Loss: 0.0248
# QA Episode 402/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2358
# Policy Loss: -1.2334
# Policy Loss: -1.2297
# QA Value Loss: 0.0247
# QA Episode 403/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2357
# Policy Loss: -1.2332
# Policy Loss: -1.2291
# QA Value Loss: 0.0247
# QA Episode 404/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2359
# Policy Loss: -1.2337
# Policy Loss: -1.2302
# QA Value Loss: 0.0246
# QA Episode 405/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2358
# Policy Loss: -1.2334
# Policy Loss: -1.2296
# QA Value Loss: 0.0246
# QA Episode 406/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1253
# Policy Loss: -1.2372
# Policy Loss: -1.2358
# Policy Loss: -1.2333
# Policy Loss: -1.2293
# QA Value Loss: 0.0245
# QA Episode 407/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2359
# Policy Loss: -1.2335
# Policy Loss: -1.2297
# QA Value Loss: 0.0245
# QA Episode 408/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2372
# Policy Loss: -1.2359
# Policy Loss: -1.2336
# Policy Loss: -1.2299
# QA Value Loss: 0.0244
# QA Episode 409/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2373
# Policy Loss: -1.2360
# Policy Loss: -1.2339
# Policy Loss: -1.2306
# QA Value Loss: 0.0244
# QA Episode 410/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2373
# Policy Loss: -1.2360
# Policy Loss: -1.2338
# Policy Loss: -1.2304
# QA Value Loss: 0.0244
# QA Episode 411/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1254
# Policy Loss: -1.2373
# Policy Loss: -1.2360
# Policy Loss: -1.2337
# Policy Loss: -1.2301
# QA Value Loss: 0.0243
# QA Episode 412/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# ...
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2376
# Policy Loss: -1.2368
# Policy Loss: -1.2355
# Policy Loss: -1.2336
# QA Value Loss: 0.0223
# QA Episode 482/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2376
# Policy Loss: -1.2368
# Policy Loss: -1.2355
# Policy Loss: -1.2335
# QA Value Loss: 0.0223
# QA Episode 483/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2376
# Policy Loss: -1.2367
# Policy Loss: -1.2352
# Policy Loss: -1.2327
# QA Value Loss: 0.0222
# QA Episode 484/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2376
# Policy Loss: -1.2367
# Policy Loss: -1.2352
# Policy Loss: -1.2328
# QA Value Loss: 0.0222
# QA Episode 485/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2377
# Policy Loss: -1.2369
# Policy Loss: -1.2356
# Policy Loss: -1.2337
# QA Value Loss: 0.0222
# QA Episode 486/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2377
# Policy Loss: -1.2371
# Policy Loss: -1.2360
# Policy Loss: -1.2344
# QA Value Loss: 0.0222
# QA Episode 487/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2376
# Policy Loss: -1.2367
# Policy Loss: -1.2351
# Policy Loss: -1.2323
# QA Value Loss: 0.0221
# QA Episode 488/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2377
# Policy Loss: -1.2368
# Policy Loss: -1.2354
# Policy Loss: -1.2332
# QA Value Loss: 0.0221
# QA Episode 489/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2377
# Policy Loss: -1.2369
# Policy Loss: -1.2356
# Policy Loss: -1.2335
# QA Value Loss: 0.0221
# QA Episode 490/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2377
# Policy Loss: -1.2368
# Policy Loss: -1.2353
# Policy Loss: -1.2329
# QA Value Loss: 0.0221
# QA Episode 491/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1256
# Policy Loss: -1.2377
# Policy Loss: -1.2370
# Policy Loss: -1.2358
# Policy Loss: -1.2339
# QA Value Loss: 0.0221
# QA Episode 492/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2377
# Policy Loss: -1.2368
# Policy Loss: -1.2354
# Policy Loss: -1.2329
# QA Value Loss: 0.0220
# QA Episode 493/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2377
# Policy Loss: -1.2371
# Policy Loss: -1.2359
# Policy Loss: -1.2342
# QA Value Loss: 0.0220
# QA Episode 494/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2376
# Policy Loss: -1.2368
# Policy Loss: -1.2353
# Policy Loss: -1.2328
# QA Value Loss: 0.0220
# QA Episode 495/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2376
# Policy Loss: -1.2368
# Policy Loss: -1.2354
# Policy Loss: -1.2331
# QA Value Loss: 0.0220
# QA Episode 496/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2377
# Policy Loss: -1.2369
# Policy Loss: -1.2356
# Policy Loss: -1.2335
# QA Value Loss: 0.0220
# QA Episode 497/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2376
# Policy Loss: -1.2368
# Policy Loss: -1.2354
# Policy Loss: -1.2330
# QA Value Loss: 0.0220
# QA Episode 498/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2376
# Policy Loss: -1.2369
# Policy Loss: -1.2355
# Policy Loss: -1.2333
# QA Value Loss: 0.0219
# QA Episode 499/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2377
# Policy Loss: -1.2369
# Policy Loss: -1.2355
# Policy Loss: -1.2333
# QA Value Loss: 0.0219
# QA Episode 500/500
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 1.5000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Task: qa, Reward: 0.0000
# Policy Loss: -1.1255
# Policy Loss: -1.2377
# Policy Loss: -1.2370
# Policy Loss: -1.2358
# Policy Loss: -1.2339
# QA Value Loss: 0.0219
# Saved RL fine-tuned DPR models for QA task.

# %%
# RL Fine-Tuning for DPR on Triple Task

# Fine-tune DPR with PPO on triple data
policy_triple = PolicyNetwork(input_dim=768, hidden_dim=256).to(CONFIG.DEVICE)
value_network_triple = PolicyNetwork(input_dim=768, hidden_dim=256).to(CONFIG.DEVICE)
policy_optimizer_triple = torch.optim.Adam(policy_triple.parameters(), lr=5e-5)
value_optimizer_triple = torch.optim.Adam(value_network_triple.parameters(), lr=5e-5)

# Create environment for triple task
triple_env = RankingEnvironment(ctx_encoder_triple, question_encoder_triple, all_candidates, candidate_embeddings_triple, triple_val_loader_v4, task="triple")

num_episodes = 500  # Reduced number of episodes
max_steps_per_episode = 50  # Maximum steps per episode

print("Fine-tuning DPR with PPO on triple data...")
for episode in range(num_episodes):
    print(f"Triple Episode {episode + 1}/{num_episodes}")
    state = triple_env.reset()
    if state.dim() == 1:
        state = state.unsqueeze(0)
    states, actions, rewards, old_log_probs, values = [], [], [], [], []
    done = False
    episode_steps = 0

    while not done and episode_steps < max_steps_per_episode:
        state = state.to(CONFIG.DEVICE)
        with torch.no_grad():
            adjustment = policy_triple(state)
            dist = torch.distributions.Normal(adjustment, 0.1)
            action = dist.sample()
            log_prob = dist.log_prob(action).sum(dim=-1)
            value = value_network_triple(state).mean()

        next_state, reward, done = triple_env.step(action)

        if next_state is not None and next_state.dim() == 1:
            next_state = next_state.unsqueeze(0)

        states.append(state)
        actions.append(action)
        rewards.append(reward)
        old_log_probs.append(log_prob)
        values.append(value.item())

        state = next_state
        episode_steps += 1

    # Compute returns and advantages
    with torch.no_grad():
        next_value = value_network_triple(state).mean().item() if state is not None else 0.0
    advantages = compute_gae(rewards, values, next_value)
    returns = [r + next_value for r in rewards]

    # Update policy and value network
    policy_loss = ppo_update(policy_triple, policy_optimizer_triple, states, actions, old_log_probs, advantages, returns)

    # Update value network
    value_loss = 0
    for state, ret in zip(states, returns):
        state = state.to(CONFIG.DEVICE)
        value = value_network_triple(state).mean()
        value_loss += (value - ret) ** 2
    value_loss = value_loss / len(states)
    value_optimizer_triple.zero_grad()
    value_loss.backward()
    value_optimizer_triple.step()
    print(f"Triple Value Loss: {value_loss.item():.4f}")

# Save fine-tuned DPR models for triple task
ctx_encoder_triple.save_pretrained(os.path.join(CONFIG.BASE_PATH, "dpr_ctx_encoder_rl_triple_v4"))
question_encoder_triple.save_pretrained(os.path.join(CONFIG.BASE_PATH, "dpr_question_encoder_rl_triple_v4"))
print("Saved RL fine-tuned DPR models for triple task.")
# Out:
# Fine-tuning DPR with PPO on triple data...
# Triple Episode 1/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 1.5000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.5000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.5000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.2000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0417
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 1.5000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0112
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0213
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0122
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: -0.7446
# Policy Loss: -0.8186
# Policy Loss: -0.8176
# Policy Loss: -0.8154
# Policy Loss: -0.8118
# Triple Value Loss: 0.1007
# Triple Episode 2/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 1.5000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.3333
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0021
# Task: triple, Reward: 1.5000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0047
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.2500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0244
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0025
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.1111
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: -0.9818
# Policy Loss: -1.0799
# Policy Loss: -1.0799
# Policy Loss: -1.0799
# Policy Loss: -1.0799
# Triple Value Loss: 0.0938
# Triple Episode 3/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0049
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0105
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0079
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0032
# Task: triple, Reward: 0.0042
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.3333
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0028
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.2500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0769
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0039
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0192
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: -0.1987
# Policy Loss: -0.2160
# Policy Loss: -0.2180
# Policy Loss: -0.2186
# Policy Loss: -0.2186
# Triple Value Loss: 0.0036
# Triple Episode 4/500
# Task: triple, Reward: 0.0034
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0048
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0023
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0116
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0066
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0026
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0026
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0066
# Policy Loss: -0.0067
# Policy Loss: -0.0067
# Policy Loss: -0.0066
# Policy Loss: -0.0066
# Triple Value Loss: 0.0000
# Triple Episode 5/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0769
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0667
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0588
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0112
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0056
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0066
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0023
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 1.5000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 1.5000
# Task: triple, Reward: 0.1250
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0096
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0074
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0086
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0417
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: -0.9055
# Policy Loss: -0.9960
# Policy Loss: -0.9960
# Policy Loss: -0.9959
# Policy Loss: -0.9959
# Triple Value Loss: 0.0906
# Triple Episode 6/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0078
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0042
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0016
# Policy Loss: 0.0016
# Policy Loss: 0.0017
# Policy Loss: 0.0018
# Policy Loss: 0.0019
# Triple Value Loss: 0.0000
# Triple Episode 7/500
# Policy Loss: 0.0080
# Policy Loss: 0.0072
# Policy Loss: 0.0072
# Policy Loss: 0.0072
# Policy Loss: 0.0072
# Triple Value Loss: 0.0001
# Triple Episode 8/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0078
# Policy Loss: 0.0070
# Policy Loss: 0.0070
# Policy Loss: 0.0070
# Policy Loss: 0.0070
# Triple Value Loss: 0.0001
# Triple Episode 9/500
# Task: triple, Reward: 0.0455
# Policy Loss: -0.0142
# Policy Loss: -0.0137
# Policy Loss: -0.0123
# Policy Loss: -0.0130
# Policy Loss: -0.0150
# Triple Value Loss: 0.0007
# Triple Episode 10/500
# Policy Loss: 0.0107
# Policy Loss: 0.0097
# Policy Loss: 0.0097
# Policy Loss: 0.0097
# Policy Loss: 0.0097
# Triple Value Loss: 0.0001
# Triple Episode 11/500
# Policy Loss: 0.0101
# Policy Loss: 0.0090
# Policy Loss: 0.0090
# Policy Loss: 0.0090
# Policy Loss: 0.0090
# Triple Value Loss: 0.0001
# Triple Episode 12/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0109
# Policy Loss: 0.0098
# Policy Loss: 0.0098
# Policy Loss: 0.0098
# Policy Loss: 0.0098
# Triple Value Loss: 0.0001
# Triple Episode 13/500
# Policy Loss: 0.0106
# Policy Loss: 0.0095
# Policy Loss: 0.0095
# Policy Loss: 0.0095
# Policy Loss: 0.0095
# Triple Value Loss: 0.0001
# Triple Episode 14/500
# Policy Loss: 0.0116
# Policy Loss: 0.0104
# Policy Loss: 0.0104
# Policy Loss: 0.0104
# Policy Loss: 0.0104
# Triple Value Loss: 0.0001
# Triple Episode 15/500
# Policy Loss: 0.0101
# Policy Loss: 0.0091
# Policy Loss: 0.0091
# Policy Loss: 0.0091
# Policy Loss: 0.0091
# Triple Value Loss: 0.0001
# Triple Episode 16/500
# Policy Loss: 0.0092
# Policy Loss: 0.0082
# Policy Loss: 0.0082
# Policy Loss: 0.0082
# Policy Loss: 0.0082
# Triple Value Loss: 0.0001
# Triple Episode 17/500
# Policy Loss: 0.0103
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Triple Value Loss: 0.0001
# Triple Episode 18/500
# Policy Loss: 0.0103
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Triple Value Loss: 0.0001
# Triple Episode 19/500
# Policy Loss: 0.0105
# Policy Loss: 0.0094
# Policy Loss: 0.0094
# Policy Loss: 0.0094
# Policy Loss: 0.0094
# Triple Value Loss: 0.0001
# Triple Episode 20/500
# Policy Loss: 0.0104
# Policy Loss: 0.0094
# Policy Loss: 0.0094
# Policy Loss: 0.0094
# Policy Loss: 0.0094
# Triple Value Loss: 0.0001
# Triple Episode 21/500
# Policy Loss: 0.0115
# Policy Loss: 0.0103
# Policy Loss: 0.0103
# Policy Loss: 0.0103
# Policy Loss: 0.0103
# Triple Value Loss: 0.0001
# Triple Episode 22/500
# Policy Loss: 0.0103
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Triple Value Loss: 0.0001
# Triple Episode 23/500
# Policy Loss: 0.0099
# Policy Loss: 0.0089
# Policy Loss: 0.0089
# Policy Loss: 0.0089
# Policy Loss: 0.0089
# Triple Value Loss: 0.0001
# Triple Episode 24/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0092
# Policy Loss: 0.0082
# Policy Loss: 0.0082
# Policy Loss: 0.0082
# Policy Loss: 0.0082
# Triple Value Loss: 0.0001
# Triple Episode 25/500
# Policy Loss: 0.0088
# Policy Loss: 0.0079
# Policy Loss: 0.0079
# Policy Loss: 0.0079
# Policy Loss: 0.0079
# Triple Value Loss: 0.0001
# Triple Episode 26/500
# Policy Loss: 0.0096
# Policy Loss: 0.0086
# Policy Loss: 0.0086
# Policy Loss: 0.0086
# Policy Loss: 0.0086
# Triple Value Loss: 0.0001
# Triple Episode 27/500
# Policy Loss: 0.0093
# Policy Loss: 0.0083
# Policy Loss: 0.0083
# Policy Loss: 0.0083
# Policy Loss: 0.0083
# Triple Value Loss: 0.0001
# Triple Episode 28/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0081
# Policy Loss: 0.0073
# Policy Loss: 0.0073
# Policy Loss: 0.0073
# Policy Loss: 0.0073
# Triple Value Loss: 0.0001
# Triple Episode 29/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0084
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Triple Value Loss: 0.0001
# Triple Episode 30/500
# Policy Loss: 0.0064
# Policy Loss: 0.0058
# Policy Loss: 0.0058
# Policy Loss: 0.0058
# Policy Loss: 0.0058
# Triple Value Loss: 0.0000
# Triple Episode 31/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0067
# Policy Loss: 0.0061
# Policy Loss: 0.0061
# Policy Loss: 0.0061
# Policy Loss: 0.0061
# Triple Value Loss: 0.0000
# Triple Episode 32/500
# Policy Loss: 0.0074
# Policy Loss: 0.0067
# Policy Loss: 0.0067
# Policy Loss: 0.0067
# Policy Loss: 0.0067
# Triple Value Loss: 0.0001
# Triple Episode 33/500
# Policy Loss: 0.0070
# Policy Loss: 0.0063
# Policy Loss: 0.0063
# Policy Loss: 0.0063
# Policy Loss: 0.0063
# Triple Value Loss: 0.0000
# Triple Episode 34/500
# Task: triple, Reward: 1.5000
# Policy Loss: -0.7451
# Policy Loss: 19.1368
# Policy Loss: -0.4831
# Policy Loss: 0.0021
# Policy Loss: 0.0023
# Triple Value Loss: 1.1174
# Triple Episode 35/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0052
# Policy Loss: 0.0065
# Policy Loss: 0.0077
# Policy Loss: 0.0081
# Policy Loss: 0.0076
# Triple Value Loss: 0.0000
# Triple Episode 36/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0081
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0021
# Policy Loss: 0.0022
# Policy Loss: 0.0024
# Policy Loss: 0.0025
# Policy Loss: 0.0026
# Triple Value Loss: 0.0000
# Triple Episode 37/500
# Policy Loss: 0.0074
# Policy Loss: 0.0070
# Policy Loss: 0.0067
# Policy Loss: 0.0067
# Policy Loss: 0.0067
# Triple Value Loss: 0.0001
# Triple Episode 38/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0069
# Policy Loss: 0.0067
# Policy Loss: 0.0063
# Policy Loss: 0.0062
# Policy Loss: 0.0062
# Triple Value Loss: 0.0001
# Triple Episode 39/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0086
# Policy Loss: 0.0084
# Policy Loss: 0.0083
# Policy Loss: 0.0080
# Policy Loss: 0.0077
# Triple Value Loss: 0.0001
# Triple Episode 40/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0083
# Policy Loss: 0.0080
# Policy Loss: 0.0079
# Policy Loss: 0.0078
# Policy Loss: 0.0075
# Triple Value Loss: 0.0001
# Triple Episode 41/500
# Policy Loss: 0.0075
# Policy Loss: 0.0067
# Policy Loss: 0.0067
# Policy Loss: 0.0067
# Policy Loss: 0.0067
# Triple Value Loss: 0.0001
# Triple Episode 42/500
# Policy Loss: 0.0090
# Policy Loss: 0.0083
# Policy Loss: 0.0081
# Policy Loss: 0.0081
# Policy Loss: 0.0081
# Triple Value Loss: 0.0001
# Triple Episode 43/500
# Policy Loss: 0.0090
# Policy Loss: 0.0081
# Policy Loss: 0.0081
# Policy Loss: 0.0081
# Policy Loss: 0.0081
# Triple Value Loss: 0.0001
# Triple Episode 44/500
# Policy Loss: 0.0091
# Policy Loss: 0.0082
# Policy Loss: 0.0082
# Policy Loss: 0.0082
# Policy Loss: 0.0082
# Triple Value Loss: 0.0001
# Triple Episode 45/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0093
# Policy Loss: 0.0088
# Policy Loss: 0.0084
# Policy Loss: 0.0084
# Policy Loss: 0.0084
# Triple Value Loss: 0.0001
# Triple Episode 46/500
# Policy Loss: 0.0096
# Policy Loss: 0.0088
# Policy Loss: 0.0086
# Policy Loss: 0.0086
# Policy Loss: 0.0086
# Triple Value Loss: 0.0001
# Triple Episode 47/500
# Policy Loss: 0.0112
# Policy Loss: 0.0101
# Policy Loss: 0.0101
# Policy Loss: 0.0101
# Policy Loss: 0.0101
# Triple Value Loss: 0.0001
# Triple Episode 48/500
# Policy Loss: 0.0100
# Policy Loss: 0.0090
# Policy Loss: 0.0090
# Policy Loss: 0.0090
# Policy Loss: 0.0090
# Triple Value Loss: 0.0001
# Triple Episode 49/500
# Policy Loss: 0.0111
# Policy Loss: 0.0100
# Policy Loss: 0.0100
# Policy Loss: 0.0100
# Policy Loss: 0.0100
# Triple Value Loss: 0.0001
# Triple Episode 50/500
# Policy Loss: 0.0089
# Policy Loss: 0.0080
# Policy Loss: 0.0080
# Policy Loss: 0.0080
# Policy Loss: 0.0080
# Triple Value Loss: 0.0001
# Triple Episode 51/500
# Policy Loss: 0.0119
# Policy Loss: 0.0108
# Policy Loss: 0.0108
# Policy Loss: 0.0108
# Policy Loss: 0.0108
# Triple Value Loss: 0.0001
# Triple Episode 52/500
# Policy Loss: 0.0114
# Policy Loss: 0.0102
# Policy Loss: 0.0102
# Policy Loss: 0.0102
# Policy Loss: 0.0102
# Triple Value Loss: 0.0001
# Triple Episode 53/500
# Policy Loss: 0.0094
# Policy Loss: 0.0084
# Policy Loss: 0.0084
# Policy Loss: 0.0084
# Policy Loss: 0.0084
# Triple Value Loss: 0.0001
# Triple Episode 54/500
# Policy Loss: 0.0101
# Policy Loss: 0.0091
# Policy Loss: 0.0091
# Policy Loss: 0.0091
# Policy Loss: 0.0091
# Triple Value Loss: 0.0001
# Triple Episode 55/500
# Policy Loss: 0.0106
# Policy Loss: 0.0095
# Policy Loss: 0.0095
# Policy Loss: 0.0095
# Policy Loss: 0.0095
# Triple Value Loss: 0.0001
# Triple Episode 56/500
# Policy Loss: 0.0103
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Policy Loss: 0.0093
# Triple Value Loss: 0.0001
# Triple Episode 57/500
# Policy Loss: 0.0099
# Policy Loss: 0.0089
# Policy Loss: 0.0089
# Policy Loss: 0.0089
# Policy Loss: 0.0089
# Triple Value Loss: 0.0001
# Triple Episode 58/500
# Policy Loss: 0.0113
# Policy Loss: 0.0102
# Policy Loss: 0.0102
# Policy Loss: 0.0102
# Policy Loss: 0.0102
# Triple Value Loss: 0.0001
# Triple Episode 59/500
# Policy Loss: 0.0084
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Triple Value Loss: 0.0001
# Triple Episode 60/500
# Policy Loss: 0.0098
# Policy Loss: 0.0088
# Policy Loss: 0.0088
# Policy Loss: 0.0088
# Policy Loss: 0.0088
# Triple Value Loss: 0.0001
# Triple Episode 61/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0088
# Policy Loss: 0.0081
# Policy Loss: 0.0080
# Policy Loss: 0.0080
# Policy Loss: 0.0080
# Triple Value Loss: 0.0001
# Triple Episode 62/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0097
# Policy Loss: 0.0088
# Policy Loss: 0.0087
# Policy Loss: 0.0087
# Policy Loss: 0.0087
# Triple Value Loss: 0.0001
# Triple Episode 63/500
# Policy Loss: 0.0095
# Policy Loss: 0.0086
# Policy Loss: 0.0086
# Policy Loss: 0.0086
# Policy Loss: 0.0086
# Triple Value Loss: 0.0001
# Triple Episode 64/500
# Policy Loss: 0.0081
# Policy Loss: 0.0073
# Policy Loss: 0.0073
# Policy Loss: 0.0073
# Policy Loss: 0.0073
# Triple Value Loss: 0.0001
# Triple Episode 65/500
# Policy Loss: 0.0085
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Triple Value Loss: 0.0001
# Triple Episode 66/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0085
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Policy Loss: 0.0076
# Triple Value Loss: 0.0001
# Triple Episode 67/500
# Policy Loss: 0.0085
# Policy Loss: 0.0077
# Policy Loss: 0.0077
# Policy Loss: 0.0077
# Policy Loss: 0.0077
# Triple Value Loss: 0.0001
# Triple Episode 68/500
# Policy Loss: 0.0073
# Policy Loss: 0.0066
# Policy Loss: 0.0066
# Policy Loss: 0.0066
# Policy Loss: 0.0066
# Triple Value Loss: 0.0001
# Triple Episode 69/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0066
# Policy Loss: 0.0062
# Policy Loss: 0.0059
# Policy Loss: 0.0059
# Policy Loss: 0.0059
# Triple Value Loss: 0.0000
# Triple Episode 70/500
# Policy Loss: 0.0069
# Policy Loss: 0.0062
# Policy Loss: 0.0062
# Policy Loss: 0.0062
# Policy Loss: 0.0062
# Triple Value Loss: 0.0000
# Triple Episode 71/500
# Policy Loss: 0.0069
# Policy Loss: 0.0062
# Policy Loss: 0.0062
# Policy Loss: 0.0062
# Policy Loss: 0.0062
# Triple Value Loss: 0.0000
# Triple Episode 72/500
# Policy Loss: 0.0060
# Policy Loss: 0.0054
# Policy Loss: 0.0054
# Policy Loss: 0.0054
# Policy Loss: 0.0054
# Triple Value Loss: 0.0000
# Triple Episode 73/500
# Policy Loss: 0.0090
# Policy Loss: 0.0081
# Policy Loss: 0.0081
# Policy Loss: 0.0081
# Policy Loss: 0.0081
# Triple Value Loss: 0.0001
# Triple Episode 74/500
# Policy Loss: 0.0048
# Policy Loss: 0.0045
# Policy Loss: 0.0043
# Policy Loss: 0.0043
# Policy Loss: 0.0043
# Triple Value Loss: 0.0000
# Triple Episode 75/500
# Policy Loss: 0.0061
# Policy Loss: 0.0055
# Policy Loss: 0.0055
# Policy Loss: 0.0055
# Policy Loss: 0.0055
# Triple Value Loss: 0.0000
# Triple Episode 76/500
# Policy Loss: 0.0052
# Policy Loss: 0.0047
# Policy Loss: 0.0047
# Policy Loss: 0.0047
# Policy Loss: 0.0047
# Triple Value Loss: 0.0000
# Triple Episode 77/500
# Policy Loss: 0.0037
# Policy Loss: 0.0035
# Policy Loss: 0.0033
# Policy Loss: 0.0033
# Policy Loss: 0.0033
# Triple Value Loss: 0.0000
# Triple Episode 78/500
# Policy Loss: 0.0051
# Policy Loss: 0.0046
# Policy Loss: 0.0046
# Policy Loss: 0.0046
# Policy Loss: 0.0046
# Triple Value Loss: 0.0000
# Triple Episode 79/500
# Policy Loss: 0.0039
# Policy Loss: 0.0035
# Policy Loss: 0.0035
# Policy Loss: 0.0035
# Policy Loss: 0.0035
# Triple Value Loss: 0.0000
# Triple Episode 80/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0043
# Policy Loss: 0.0040
# Policy Loss: 0.0038
# Policy Loss: 0.0038
# Policy Loss: 0.0038
# Triple Value Loss: 0.0000
# Triple Episode 81/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0032
# Policy Loss: 0.0031
# Policy Loss: 0.0030
# Policy Loss: 0.0029
# Policy Loss: 0.0029
# Triple Value Loss: 0.0000
# Triple Episode 82/500
# Policy Loss: 0.0053
# Policy Loss: 0.0048
# Policy Loss: 0.0048
# Policy Loss: 0.0048
# Policy Loss: 0.0048
# Triple Value Loss: 0.0000
# Triple Episode 83/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0033
# Policy Loss: 0.0032
# Policy Loss: 0.0030
# Policy Loss: 0.0029
# Policy Loss: 0.0029
# Triple Value Loss: 0.0000
# Triple Episode 84/500
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Triple Value Loss: 0.0000
# Triple Episode 85/500
# Policy Loss: 0.0028
# Policy Loss: 0.0026
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Triple Value Loss: 0.0000
# Triple Episode 86/500
# Policy Loss: 0.0023
# Policy Loss: 0.0021
# Policy Loss: 0.0021
# Policy Loss: 0.0021
# Policy Loss: 0.0021
# Triple Value Loss: 0.0000
# Triple Episode 87/500
# Policy Loss: 0.0021
# Policy Loss: 0.0020
# Policy Loss: 0.0019
# Policy Loss: 0.0019
# Policy Loss: 0.0019
# Triple Value Loss: 0.0000
# Triple Episode 88/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0010
# Policy Loss: 0.0010
# Policy Loss: 0.0010
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Triple Value Loss: 0.0000
# Triple Episode 89/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Triple Value Loss: 0.0000
# Triple Episode 90/500
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Triple Value Loss: 0.0000
# Triple Episode 91/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Triple Value Loss: 0.0000
# Triple Episode 92/500
# Policy Loss: 0.0017
# Policy Loss: 0.0016
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Triple Value Loss: 0.0000
# Triple Episode 93/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 94/500
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0005
# Triple Value Loss: 0.0000
# Triple Episode 95/500
# Policy Loss: -0.0023
# Policy Loss: -0.0025
# Policy Loss: -0.0026
# Policy Loss: -0.0026
# Policy Loss: -0.0026
# Triple Value Loss: 0.0000
# Triple Episode 96/500
# Policy Loss: -0.0037
# Policy Loss: -0.0041
# Policy Loss: -0.0041
# Policy Loss: -0.0041
# Policy Loss: -0.0041
# Triple Value Loss: 0.0000
# Triple Episode 97/500
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Triple Value Loss: 0.0000
# Triple Episode 98/500
# Policy Loss: -0.0015
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Triple Value Loss: 0.0000
# Triple Episode 99/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Triple Value Loss: 0.0000
# Triple Episode 100/500
# Policy Loss: -0.0013
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Triple Value Loss: 0.0000
# Triple Episode 101/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0009
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Triple Value Loss: 0.0000
# Triple Episode 102/500
# Policy Loss: 0.0024
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Triple Value Loss: 0.0000
# Triple Episode 103/500
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Triple Value Loss: 0.0000
# Triple Episode 104/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0011
# Policy Loss: -0.0011
# Policy Loss: -0.0012
# Policy Loss: -0.0012
# Policy Loss: -0.0012
# Triple Value Loss: 0.0000
# Triple Episode 105/500
# Task: triple, Reward: 0.0303
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0095
# Policy Loss: -0.0104
# Policy Loss: -0.0105
# Policy Loss: -0.0104
# Policy Loss: -0.0104
# Triple Value Loss: 0.0003
# Triple Episode 106/500
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Triple Value Loss: 0.0000
# Triple Episode 107/500
# Policy Loss: -0.0009
# Policy Loss: -0.0009
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Triple Value Loss: 0.0000
# Triple Episode 108/500
# Policy Loss: 0.0019
# Policy Loss: 0.0018
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Triple Value Loss: 0.0000
# Triple Episode 109/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Triple Value Loss: 0.0000
# Triple Episode 110/500
# Policy Loss: 0.0017
# Policy Loss: 0.0016
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Triple Value Loss: 0.0000
# Triple Episode 111/500
# Policy Loss: -0.0004
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Triple Value Loss: 0.0000
# Triple Episode 112/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Triple Value Loss: 0.0000
# Triple Episode 113/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0007
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Triple Value Loss: 0.0000
# Triple Episode 114/500
# Task: triple, Reward: 0.0278
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0090
# Policy Loss: -0.0099
# Policy Loss: -0.0099
# Policy Loss: -0.0099
# Policy Loss: -0.0099
# Triple Value Loss: 0.0002
# Triple Episode 115/500
# Policy Loss: 0.0005
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Triple Value Loss: 0.0000
# Triple Episode 116/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Triple Value Loss: 0.0000
# Triple Episode 117/500
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Triple Value Loss: 0.0000
# Triple Episode 118/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0015
# Policy Loss: -0.0016
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Triple Value Loss: 0.0000
# Triple Episode 119/500
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Triple Value Loss: 0.0000
# Triple Episode 120/500
# Policy Loss: 0.0017
# Policy Loss: 0.0016
# Policy Loss: 0.0016
# Policy Loss: 0.0016
# Policy Loss: 0.0016
# Triple Value Loss: 0.0000
# Triple Episode 121/500
# Policy Loss: 0.0024
# Policy Loss: 0.0023
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Triple Value Loss: 0.0000
# Triple Episode 122/500
# Policy Loss: 0.0016
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Triple Value Loss: 0.0000
# Triple Episode 123/500
# Task: triple, Reward: 0.1667
# Policy Loss: -0.0825
# Policy Loss: -0.0897
# Policy Loss: -0.0875
# Policy Loss: -0.0836
# Policy Loss: -0.0782
# Triple Value Loss: 0.0138
# Triple Episode 124/500
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Triple Value Loss: 0.0000
# Triple Episode 125/500
# Policy Loss: 0.0011
# Policy Loss: 0.0011
# Policy Loss: 0.0010
# Policy Loss: 0.0010
# Policy Loss: 0.0010
# Triple Value Loss: 0.0000
# Triple Episode 126/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0014
# Policy Loss: 0.0013
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Triple Value Loss: 0.0000
# Triple Episode 127/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0016
# Policy Loss: 0.0015
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Triple Value Loss: 0.0000
# Triple Episode 128/500
# Policy Loss: 0.0038
# Policy Loss: 0.0034
# Policy Loss: 0.0034
# Policy Loss: 0.0034
# Policy Loss: 0.0034
# Triple Value Loss: 0.0000
# Triple Episode 129/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0035
# Policy Loss: 0.0033
# Policy Loss: 0.0031
# Policy Loss: 0.0031
# Policy Loss: 0.0031
# Triple Value Loss: 0.0000
# Triple Episode 130/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0025
# Policy Loss: 0.0023
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Triple Value Loss: 0.0000
# Triple Episode 131/500
# Policy Loss: 0.0022
# Policy Loss: 0.0020
# Policy Loss: 0.0020
# Policy Loss: 0.0020
# Policy Loss: 0.0020
# Triple Value Loss: 0.0000
# Triple Episode 132/500
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Triple Value Loss: 0.0000
# Triple Episode 133/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0032
# Policy Loss: 0.0030
# Policy Loss: 0.0029
# Policy Loss: 0.0029
# Policy Loss: 0.0029
# Triple Value Loss: 0.0000
# Triple Episode 134/500
# Policy Loss: 0.0030
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Triple Value Loss: 0.0000
# Triple Episode 135/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0078
# Policy Loss: -0.0031
# Policy Loss: -0.0032
# Policy Loss: -0.0033
# Policy Loss: -0.0034
# Policy Loss: -0.0034
# Triple Value Loss: 0.0000
# Triple Episode 136/500
# Policy Loss: 0.0019
# Policy Loss: 0.0018
# Policy Loss: 0.0018
# Policy Loss: 0.0018
# Policy Loss: 0.0018
# Triple Value Loss: 0.0000
# Triple Episode 137/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0040
# Policy Loss: 0.0038
# Policy Loss: 0.0036
# Policy Loss: 0.0036
# Policy Loss: 0.0036
# Triple Value Loss: 0.0000
# Triple Episode 138/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0031
# Policy Loss: 0.0028
# Policy Loss: 0.0028
# Policy Loss: 0.0028
# Policy Loss: 0.0028
# Triple Value Loss: 0.0000
# Triple Episode 139/500
# Policy Loss: 0.0045
# Policy Loss: 0.0040
# Policy Loss: 0.0040
# Policy Loss: 0.0040
# Policy Loss: 0.0040
# Triple Value Loss: 0.0000
# Triple Episode 140/500
# Policy Loss: 0.0027
# Policy Loss: 0.0025
# Policy Loss: 0.0024
# Policy Loss: 0.0024
# Policy Loss: 0.0024
# Triple Value Loss: 0.0000
# Triple Episode 141/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0017
# Policy Loss: 0.0016
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Triple Value Loss: 0.0000
# Triple Episode 142/500
# Policy Loss: 0.0030
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Triple Value Loss: 0.0000
# Triple Episode 143/500
# Policy Loss: 0.0033
# Policy Loss: 0.0030
# Policy Loss: 0.0030
# Policy Loss: 0.0030
# Policy Loss: 0.0030
# Triple Value Loss: 0.0000
# Triple Episode 144/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0026
# Policy Loss: 0.0025
# Policy Loss: 0.0024
# Policy Loss: 0.0024
# Policy Loss: 0.0024
# Triple Value Loss: 0.0000
# Triple Episode 145/500
# Policy Loss: 0.0030
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Triple Value Loss: 0.0000
# Triple Episode 146/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0041
# Policy Loss: 0.0037
# Policy Loss: 0.0037
# Policy Loss: 0.0037
# Policy Loss: 0.0037
# Triple Value Loss: 0.0000
# Triple Episode 147/500
# Task: triple, Reward: 0.0023
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Triple Value Loss: 0.0000
# Triple Episode 148/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0027
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Triple Value Loss: 0.0000
# Triple Episode 149/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0020
# Policy Loss: 0.0019
# Policy Loss: 0.0018
# Policy Loss: 0.0018
# Policy Loss: 0.0018
# Triple Value Loss: 0.0000
# Triple Episode 150/500
# Policy Loss: 0.0014
# Policy Loss: 0.0013
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Triple Value Loss: 0.0000
# Triple Episode 151/500
# Task: triple, Reward: 0.1000
# Policy Loss: -0.0475
# Policy Loss: -0.0501
# Policy Loss: -0.0464
# Policy Loss: -0.0420
# Policy Loss: -0.0398
# Triple Value Loss: 0.0048
# Triple Episode 152/500
# Policy Loss: 0.0021
# Policy Loss: 0.0019
# Policy Loss: 0.0019
# Policy Loss: 0.0019
# Policy Loss: 0.0019
# Triple Value Loss: 0.0000
# Triple Episode 153/500
# Policy Loss: 0.0040
# Policy Loss: 0.0036
# Policy Loss: 0.0036
# Policy Loss: 0.0036
# Policy Loss: 0.0036
# Triple Value Loss: 0.0000
# Triple Episode 154/500
# Policy Loss: 0.0011
# Policy Loss: 0.0011
# Policy Loss: 0.0010
# Policy Loss: 0.0010
# Policy Loss: 0.0010
# Triple Value Loss: 0.0000
# Triple Episode 155/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0021
# Policy Loss: 0.0020
# Policy Loss: 0.0019
# Policy Loss: 0.0018
# Policy Loss: 0.0018
# Triple Value Loss: 0.0000
# Triple Episode 156/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.5000
# Policy Loss: -0.3211
# Policy Loss: -0.3498
# Policy Loss: -0.3293
# Policy Loss: -0.2594
# Policy Loss: -0.2241
# Triple Value Loss: 0.0819
# Triple Episode 157/500
# Policy Loss: 0.0047
# Policy Loss: 0.0042
# Policy Loss: 0.0042
# Policy Loss: 0.0042
# Policy Loss: 0.0042
# Triple Value Loss: 0.0000
# Triple Episode 158/500
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Policy Loss: 0.0023
# Policy Loss: 0.0023
# Policy Loss: 0.0023
# Triple Value Loss: 0.0000
# Triple Episode 159/500
# Policy Loss: 0.0043
# Policy Loss: 0.0040
# Policy Loss: 0.0039
# Policy Loss: 0.0039
# Policy Loss: 0.0039
# Triple Value Loss: 0.0000
# Triple Episode 160/500
# Policy Loss: 0.0058
# Policy Loss: 0.0052
# Policy Loss: 0.0052
# Policy Loss: 0.0052
# Policy Loss: 0.0052
# Triple Value Loss: 0.0000
# Triple Episode 161/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0050
# Policy Loss: 0.0048
# Policy Loss: 0.0045
# Policy Loss: 0.0045
# Policy Loss: 0.0045
# Triple Value Loss: 0.0000
# Triple Episode 162/500
# Policy Loss: 0.0046
# Policy Loss: 0.0041
# Policy Loss: 0.0041
# Policy Loss: 0.0041
# Policy Loss: 0.0041
# Triple Value Loss: 0.0000
# Triple Episode 163/500
# Policy Loss: 0.0059
# Policy Loss: 0.0053
# Policy Loss: 0.0053
# Policy Loss: 0.0053
# Policy Loss: 0.0053
# Triple Value Loss: 0.0000
# Triple Episode 164/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0034
# Policy Loss: 0.0032
# Policy Loss: 0.0031
# Policy Loss: 0.0031
# Policy Loss: 0.0031
# Triple Value Loss: 0.0000
# Triple Episode 165/500
# Policy Loss: 0.0064
# Policy Loss: 0.0058
# Policy Loss: 0.0058
# Policy Loss: 0.0058
# Policy Loss: 0.0058
# Triple Value Loss: 0.0000
# Triple Episode 166/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0051
# Policy Loss: 0.0047
# Policy Loss: 0.0046
# Policy Loss: 0.0046
# Policy Loss: 0.0046
# Triple Value Loss: 0.0000
# Triple Episode 167/500
# Policy Loss: 0.0064
# Policy Loss: 0.0057
# Policy Loss: 0.0057
# Policy Loss: 0.0057
# Policy Loss: 0.0057
# Triple Value Loss: 0.0000
# Triple Episode 168/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0047
# Policy Loss: 0.0044
# Policy Loss: 0.0042
# Policy Loss: 0.0042
# Policy Loss: 0.0042
# Triple Value Loss: 0.0000
# Triple Episode 169/500
# Policy Loss: 0.0055
# Policy Loss: 0.0050
# Policy Loss: 0.0050
# Policy Loss: 0.0050
# Policy Loss: 0.0050
# Triple Value Loss: 0.0000
# Triple Episode 170/500
# Policy Loss: 0.0057
# Policy Loss: 0.0052
# Policy Loss: 0.0052
# Policy Loss: 0.0052
# Policy Loss: 0.0052
# Triple Value Loss: 0.0000
# Triple Episode 171/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0064
# Policy Loss: 0.0057
# Policy Loss: 0.0057
# Policy Loss: 0.0057
# Policy Loss: 0.0057
# Triple Value Loss: 0.0000
# Triple Episode 172/500
# Task: triple, Reward: 0.0069
# Policy Loss: 0.0025
# Policy Loss: 0.0024
# Policy Loss: 0.0024
# Policy Loss: 0.0024
# Policy Loss: 0.0024
# Triple Value Loss: 0.0000
# Triple Episode 173/500
# Policy Loss: 0.0066
# Policy Loss: 0.0059
# Policy Loss: 0.0059
# Policy Loss: 0.0059
# Policy Loss: 0.0059
# Triple Value Loss: 0.0000
# Triple Episode 174/500
# Policy Loss: 0.0042
# Policy Loss: 0.0038
# Policy Loss: 0.0038
# Policy Loss: 0.0038
# Policy Loss: 0.0038
# Triple Value Loss: 0.0000
# Triple Episode 175/500
# Policy Loss: 0.0049
# Policy Loss: 0.0044
# Policy Loss: 0.0044
# Policy Loss: 0.0044
# Policy Loss: 0.0044
# Triple Value Loss: 0.0000
# Triple Episode 176/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0059
# Policy Loss: 0.0053
# Policy Loss: 0.0053
# Policy Loss: 0.0053
# Policy Loss: 0.0053
# Triple Value Loss: 0.0000
# Triple Episode 177/500
# Policy Loss: 0.0068
# Policy Loss: 0.0061
# Policy Loss: 0.0061
# Policy Loss: 0.0061
# Policy Loss: 0.0061
# Triple Value Loss: 0.0000
# Triple Episode 178/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0052
# Policy Loss: 0.0049
# Policy Loss: 0.0047
# Policy Loss: 0.0047
# Policy Loss: 0.0047
# Triple Value Loss: 0.0000
# Triple Episode 179/500
# Policy Loss: 0.0052
# Policy Loss: 0.0047
# Policy Loss: 0.0047
# Policy Loss: 0.0047
# Policy Loss: 0.0047
# Triple Value Loss: 0.0000
# Triple Episode 180/500
# Policy Loss: 0.0052
# Policy Loss: 0.0047
# Policy Loss: 0.0047
# Policy Loss: 0.0047
# Policy Loss: 0.0047
# Triple Value Loss: 0.0000
# Triple Episode 181/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0044
# Policy Loss: 0.0042
# Policy Loss: 0.0040
# Policy Loss: 0.0040
# Policy Loss: 0.0040
# Triple Value Loss: 0.0000
# Triple Episode 182/500
# Policy Loss: 0.0040
# Policy Loss: 0.0036
# Policy Loss: 0.0036
# Policy Loss: 0.0036
# Policy Loss: 0.0036
# Triple Value Loss: 0.0000
# Triple Episode 183/500
# Policy Loss: 0.0053
# Policy Loss: 0.0048
# Policy Loss: 0.0048
# Policy Loss: 0.0048
# Policy Loss: 0.0048
# Triple Value Loss: 0.0000
# Triple Episode 184/500
# Policy Loss: 0.0030
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Policy Loss: 0.0027
# Triple Value Loss: 0.0000
# Triple Episode 185/500
# Policy Loss: 0.0040
# Policy Loss: 0.0036
# Policy Loss: 0.0036
# Policy Loss: 0.0036
# Policy Loss: 0.0036
# Triple Value Loss: 0.0000
# Triple Episode 186/500
# Policy Loss: 0.0028
# Policy Loss: 0.0026
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Triple Value Loss: 0.0000
# Triple Episode 187/500
# Policy Loss: 0.0035
# Policy Loss: 0.0031
# Policy Loss: 0.0031
# Policy Loss: 0.0031
# Policy Loss: 0.0031
# Triple Value Loss: 0.0000
# Triple Episode 188/500
# Policy Loss: 0.0022
# Policy Loss: 0.0020
# Policy Loss: 0.0019
# Policy Loss: 0.0019
# Policy Loss: 0.0019
# Triple Value Loss: 0.0000
# Triple Episode 189/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0028
# Policy Loss: 0.0026
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Triple Value Loss: 0.0000
# Triple Episode 190/500
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Triple Value Loss: 0.0000
# Triple Episode 191/500
# Policy Loss: 0.0022
# Policy Loss: 0.0020
# Policy Loss: 0.0020
# Policy Loss: 0.0020
# Policy Loss: 0.0020
# Triple Value Loss: 0.0000
# Triple Episode 192/500
# Policy Loss: 0.0019
# Policy Loss: 0.0018
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Triple Value Loss: 0.0000
# Triple Episode 193/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0008
# Triple Value Loss: 0.0000
# Triple Episode 194/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0028
# Policy Loss: 0.0026
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Policy Loss: 0.0025
# Triple Value Loss: 0.0000
# Triple Episode 195/500
# Policy Loss: 0.0022
# Policy Loss: 0.0021
# Policy Loss: 0.0020
# Policy Loss: 0.0020
# Policy Loss: 0.0020
# Triple Value Loss: 0.0000
# Triple Episode 196/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Policy Loss: 0.0013
# Policy Loss: 0.0013
# Policy Loss: 0.0013
# Triple Value Loss: 0.0000
# Triple Episode 197/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Triple Value Loss: 0.0000
# Triple Episode 198/500
# Policy Loss: 0.0024
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Triple Value Loss: 0.0000
# Triple Episode 199/500
# Policy Loss: 0.0010
# Policy Loss: 0.0010
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Triple Value Loss: 0.0000
# Triple Episode 200/500
# Policy Loss: 0.0016
# Policy Loss: 0.0015
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Triple Value Loss: 0.0000
# Triple Episode 201/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0010
# Policy Loss: -0.0011
# Policy Loss: -0.0011
# Policy Loss: -0.0011
# Policy Loss: -0.0011
# Triple Value Loss: 0.0000
# Triple Episode 202/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0011
# Policy Loss: -0.0011
# Triple Value Loss: 0.0000
# Triple Episode 203/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0014
# Policy Loss: -0.0014
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Triple Value Loss: 0.0000
# Triple Episode 204/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Triple Value Loss: 0.0000
# Triple Episode 205/500
# Policy Loss: -0.0003
# Policy Loss: -0.0003
# Policy Loss: -0.0003
# Policy Loss: -0.0003
# Policy Loss: -0.0003
# Triple Value Loss: 0.0000
# Triple Episode 206/500
# Policy Loss: 0.0021
# Policy Loss: 0.0019
# Policy Loss: 0.0019
# Policy Loss: 0.0019
# Policy Loss: 0.0019
# Triple Value Loss: 0.0000
# Triple Episode 207/500
# Policy Loss: 0.0014
# Policy Loss: 0.0013
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Triple Value Loss: 0.0000
# Triple Episode 208/500
# Policy Loss: -0.0029
# Policy Loss: -0.0032
# Policy Loss: -0.0032
# Policy Loss: -0.0032
# Policy Loss: -0.0032
# Triple Value Loss: 0.0000
# Triple Episode 209/500
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Triple Value Loss: 0.0000
# Triple Episode 210/500
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Triple Value Loss: 0.0000
# Triple Episode 211/500
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Triple Value Loss: 0.0000
# Triple Episode 212/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 213/500
# Policy Loss: 0.0003
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Triple Value Loss: 0.0000
# Triple Episode 214/500
# Policy Loss: -0.0022
# Policy Loss: -0.0024
# Policy Loss: -0.0024
# Policy Loss: -0.0024
# Policy Loss: -0.0024
# Triple Value Loss: 0.0000
# Triple Episode 215/500
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Triple Value Loss: 0.0000
# Triple Episode 216/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0011
# Policy Loss: -0.0011
# Policy Loss: -0.0012
# Policy Loss: -0.0012
# Policy Loss: -0.0012
# Triple Value Loss: 0.0000
# Triple Episode 217/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 218/500
# Policy Loss: -0.0019
# Policy Loss: -0.0020
# Policy Loss: -0.0021
# Policy Loss: -0.0021
# Policy Loss: -0.0021
# Triple Value Loss: 0.0000
# Triple Episode 219/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0020
# Policy Loss: -0.0021
# Policy Loss: -0.0022
# Policy Loss: -0.0022
# Policy Loss: -0.0022
# Triple Value Loss: 0.0000
# Triple Episode 220/500
# Policy Loss: -0.0020
# Policy Loss: -0.0022
# Policy Loss: -0.0022
# Policy Loss: -0.0022
# Policy Loss: -0.0022
# Triple Value Loss: 0.0000
# Triple Episode 221/500
# Policy Loss: -0.0009
# Policy Loss: -0.0009
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Triple Value Loss: 0.0000
# Triple Episode 222/500
# Policy Loss: -0.0009
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Triple Value Loss: 0.0000
# Triple Episode 223/500
# Policy Loss: 0.0010
# Policy Loss: 0.0010
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Triple Value Loss: 0.0000
# Triple Episode 224/500
# Policy Loss: -0.0028
# Policy Loss: -0.0030
# Policy Loss: -0.0030
# Policy Loss: -0.0030
# Policy Loss: -0.0030
# Triple Value Loss: 0.0000
# Triple Episode 225/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0017
# Policy Loss: -0.0018
# Policy Loss: -0.0019
# Policy Loss: -0.0019
# Policy Loss: -0.0019
# Triple Value Loss: 0.0000
# Triple Episode 226/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0014
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Policy Loss: -0.0016
# Policy Loss: -0.0016
# Triple Value Loss: 0.0000
# Triple Episode 227/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Triple Value Loss: 0.0000
# Triple Episode 228/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Triple Value Loss: 0.0000
# Triple Episode 229/500
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Triple Value Loss: 0.0000
# Triple Episode 230/500
# Policy Loss: -0.0002
# Policy Loss: -0.0002
# Policy Loss: -0.0002
# Policy Loss: -0.0002
# Policy Loss: -0.0002
# Triple Value Loss: 0.0000
# Triple Episode 231/500
# Policy Loss: -0.0009
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Triple Value Loss: 0.0000
# Triple Episode 232/500
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Triple Value Loss: 0.0000
# Triple Episode 233/500
# Policy Loss: 0.0025
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Policy Loss: 0.0022
# Triple Value Loss: 0.0000
# Triple Episode 234/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Triple Value Loss: 0.0000
# Triple Episode 235/500
# Policy Loss: -0.0002
# Policy Loss: -0.0002
# Policy Loss: -0.0003
# Policy Loss: -0.0003
# Policy Loss: -0.0003
# Triple Value Loss: 0.0000
# Triple Episode 236/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0185
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0086
# Policy Loss: -0.0094
# Policy Loss: -0.0095
# Policy Loss: -0.0094
# Policy Loss: -0.0093
# Triple Value Loss: 0.0001
# Triple Episode 237/500
# Policy Loss: 0.0037
# Policy Loss: 0.0033
# Policy Loss: 0.0033
# Policy Loss: 0.0033
# Policy Loss: 0.0033
# Triple Value Loss: 0.0000
# Triple Episode 238/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 239/500
# Policy Loss: 0.0023
# Policy Loss: 0.0021
# Policy Loss: 0.0021
# Policy Loss: 0.0021
# Policy Loss: 0.0021
# Triple Value Loss: 0.0000
# Triple Episode 240/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Triple Value Loss: 0.0000
# Triple Episode 241/500
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Triple Value Loss: 0.0000
# Triple Episode 242/500
# Policy Loss: 0.0019
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Triple Value Loss: 0.0000
# Triple Episode 243/500
# Policy Loss: 0.0011
# Policy Loss: 0.0011
# Policy Loss: 0.0010
# Policy Loss: 0.0010
# Policy Loss: 0.0010
# Triple Value Loss: 0.0000
# Triple Episode 244/500
# Policy Loss: 0.0021
# Policy Loss: 0.0018
# Policy Loss: 0.0018
# Policy Loss: 0.0018
# Policy Loss: 0.0018
# Triple Value Loss: 0.0000
# Triple Episode 245/500
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Triple Value Loss: 0.0000
# Triple Episode 246/500
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Triple Value Loss: 0.0000
# Triple Episode 247/500
# ...
# Policy Loss: 0.0014
# Policy Loss: 0.0013
# Policy Loss: 0.0013
# Policy Loss: 0.0014
# Triple Value Loss: 0.0000
# Triple Episode 401/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0019
# Policy Loss: 0.0018
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Triple Value Loss: 0.0000
# Triple Episode 402/500
# Policy Loss: 0.0008
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Triple Value Loss: 0.0000
# Triple Episode 403/500
# Policy Loss: 0.0017
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Triple Value Loss: 0.0000
# Triple Episode 404/500
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Triple Value Loss: 0.0000
# Triple Episode 405/500
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Triple Value Loss: 0.0000
# Triple Episode 406/500
# Policy Loss: 0.0029
# Policy Loss: 0.0026
# Policy Loss: 0.0026
# Policy Loss: 0.0026
# Policy Loss: 0.0026
# Triple Value Loss: 0.0000
# Triple Episode 407/500
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Triple Value Loss: 0.0000
# Triple Episode 408/500
# Task: triple, Reward: 0.0060
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Triple Value Loss: 0.0000
# Triple Episode 409/500
# Policy Loss: -0.0002
# Policy Loss: -0.0002
# Policy Loss: -0.0002
# Policy Loss: -0.0002
# Policy Loss: -0.0002
# Triple Value Loss: 0.0000
# Triple Episode 410/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Triple Value Loss: 0.0000
# Triple Episode 411/500
# Policy Loss: 0.0029
# Policy Loss: 0.0026
# Policy Loss: 0.0026
# Policy Loss: 0.0026
# Policy Loss: 0.0026
# Triple Value Loss: 0.0000
# Triple Episode 412/500
# Policy Loss: -0.0014
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Triple Value Loss: 0.0000
# Triple Episode 413/500
# Policy Loss: -0.0011
# Policy Loss: -0.0012
# Policy Loss: -0.0012
# Policy Loss: -0.0012
# Policy Loss: -0.0012
# Triple Value Loss: 0.0000
# Triple Episode 414/500
# Policy Loss: 0.0008
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Triple Value Loss: 0.0000
# Triple Episode 415/500
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0011
# Policy Loss: -0.0011
# Policy Loss: -0.0011
# Triple Value Loss: 0.0000
# Triple Episode 416/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 417/500
# Policy Loss: 0.0006
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Triple Value Loss: 0.0000
# Triple Episode 418/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Triple Value Loss: 0.0000
# Triple Episode 419/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 420/500
# Policy Loss: -0.0017
# Policy Loss: -0.0018
# Policy Loss: -0.0018
# Policy Loss: -0.0018
# Policy Loss: -0.0018
# Triple Value Loss: 0.0000
# Triple Episode 421/500
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Triple Value Loss: 0.0000
# Triple Episode 422/500
# Policy Loss: 0.0019
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Triple Value Loss: 0.0000
# Triple Episode 423/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 424/500
# Policy Loss: 0.0010
# Policy Loss: 0.0010
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Triple Value Loss: 0.0000
# Triple Episode 425/500
# Policy Loss: 0.0017
# Policy Loss: 0.0016
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Triple Value Loss: 0.0000
# Triple Episode 426/500
# Policy Loss: -0.0012
# Policy Loss: -0.0013
# Policy Loss: -0.0013
# Policy Loss: -0.0013
# Policy Loss: -0.0013
# Triple Value Loss: 0.0000
# Triple Episode 427/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0014
# Policy Loss: 0.0013
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Triple Value Loss: 0.0000
# Triple Episode 428/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Triple Value Loss: 0.0000
# Triple Episode 429/500
# Policy Loss: -0.0016
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Triple Value Loss: 0.0000
# Triple Episode 430/500
# Policy Loss: 0.0031
# Policy Loss: 0.0028
# Policy Loss: 0.0028
# Policy Loss: 0.0028
# Policy Loss: 0.0028
# Triple Value Loss: 0.0000
# Triple Episode 431/500
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Triple Value Loss: 0.0000
# Triple Episode 432/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Policy Loss: 0.0013
# Policy Loss: 0.0013
# Policy Loss: 0.0013
# Triple Value Loss: 0.0000
# Triple Episode 433/500
# Policy Loss: -0.0013
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Policy Loss: -0.0015
# Triple Value Loss: 0.0000
# Triple Episode 434/500
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Triple Value Loss: 0.0000
# Triple Episode 435/500
# Policy Loss: 0.0016
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Policy Loss: 0.0014
# Triple Value Loss: 0.0000
# Triple Episode 436/500
# Policy Loss: 0.0014
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Triple Value Loss: 0.0000
# Triple Episode 437/500
# Policy Loss: 0.0006
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Triple Value Loss: 0.0000
# Triple Episode 438/500
# Policy Loss: 0.0006
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Triple Value Loss: 0.0000
# Triple Episode 439/500
# Policy Loss: -0.0003
# Policy Loss: -0.0003
# Policy Loss: -0.0003
# Policy Loss: -0.0003
# Policy Loss: -0.0003
# Triple Value Loss: 0.0000
# Triple Episode 440/500
# Policy Loss: -0.0007
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Triple Value Loss: 0.0000
# Triple Episode 441/500
# Policy Loss: -0.0010
# Policy Loss: -0.0010
# Policy Loss: -0.0011
# Policy Loss: -0.0011
# Policy Loss: -0.0011
# Triple Value Loss: 0.0000
# Triple Episode 442/500
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Triple Value Loss: 0.0000
# Triple Episode 443/500
# Policy Loss: -0.0015
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Triple Value Loss: 0.0000
# Triple Episode 444/500
# Policy Loss: -0.0017
# Policy Loss: -0.0019
# Policy Loss: -0.0019
# Policy Loss: -0.0019
# Policy Loss: -0.0019
# Triple Value Loss: 0.0000
# Triple Episode 445/500
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Triple Value Loss: 0.0000
# Triple Episode 446/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Triple Value Loss: 0.0000
# Triple Episode 447/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0005
# Triple Value Loss: 0.0000
# Triple Episode 448/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Policy Loss: 0.0005
# Policy Loss: 0.0006
# Triple Value Loss: 0.0000
# Triple Episode 449/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0011
# Policy Loss: -0.0011
# Policy Loss: -0.0012
# Policy Loss: -0.0012
# Policy Loss: -0.0012
# Triple Value Loss: 0.0000
# Triple Episode 450/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 451/500
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0001
# Policy Loss: -0.0002
# Triple Value Loss: 0.0000
# Triple Episode 452/500
# Policy Loss: -0.0008
# Policy Loss: -0.0009
# Policy Loss: -0.0009
# Policy Loss: -0.0009
# Policy Loss: -0.0009
# Triple Value Loss: 0.0000
# Triple Episode 453/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Triple Value Loss: 0.0000
# Triple Episode 454/500
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Triple Value Loss: 0.0000
# Triple Episode 455/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 456/500
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Policy Loss: 0.0000
# Triple Value Loss: 0.0000
# Triple Episode 457/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Triple Value Loss: 0.0000
# Triple Episode 458/500
# Policy Loss: 0.0023
# Policy Loss: 0.0020
# Policy Loss: 0.0020
# Policy Loss: 0.0020
# Policy Loss: 0.0020
# Triple Value Loss: 0.0000
# Triple Episode 459/500
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Triple Value Loss: 0.0000
# Triple Episode 460/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 461/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0016
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Policy Loss: -0.0017
# Triple Value Loss: 0.0000
# Triple Episode 462/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0002
# Triple Value Loss: 0.0000
# Triple Episode 463/500
# Task: triple, Reward: 0.0167
# Policy Loss: -0.0088
# Policy Loss: -0.0097
# Policy Loss: -0.0097
# Policy Loss: -0.0097
# Policy Loss: -0.0097
# Triple Value Loss: 0.0001
# Triple Episode 464/500
# Policy Loss: 0.0019
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Policy Loss: 0.0017
# Triple Value Loss: 0.0000
# Triple Episode 465/500
# Policy Loss: -0.0012
# Policy Loss: -0.0014
# Policy Loss: -0.0014
# Policy Loss: -0.0014
# Policy Loss: -0.0014
# Triple Value Loss: 0.0000
# Triple Episode 466/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 467/500
# Policy Loss: 0.0010
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Triple Value Loss: 0.0000
# Triple Episode 468/500
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Triple Value Loss: 0.0000
# Triple Episode 469/500
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0004
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Triple Value Loss: 0.0000
# Triple Episode 470/500
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Triple Value Loss: 0.0000
# Triple Episode 471/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Triple Value Loss: 0.0000
# Triple Episode 472/500
# Policy Loss: 0.0009
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Triple Value Loss: 0.0000
# Triple Episode 473/500
# Policy Loss: -0.0005
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Triple Value Loss: 0.0000
# Triple Episode 474/500
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Policy Loss: -0.0004
# Triple Value Loss: 0.0000
# Triple Episode 475/500
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Triple Value Loss: 0.0000
# Triple Episode 476/500
# Policy Loss: -0.0006
# Policy Loss: -0.0006
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Triple Value Loss: 0.0000
# Triple Episode 477/500
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Policy Loss: 0.0005
# Triple Value Loss: 0.0000
# Triple Episode 478/500
# Policy Loss: -0.0008
# Policy Loss: -0.0009
# Policy Loss: -0.0009
# Policy Loss: -0.0009
# Policy Loss: -0.0009
# Triple Value Loss: 0.0000
# Triple Episode 479/500
# Policy Loss: 0.0008
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Triple Value Loss: 0.0000
# Triple Episode 480/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0008
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Triple Value Loss: 0.0000
# Triple Episode 481/500
# Policy Loss: 0.0017
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Policy Loss: 0.0015
# Triple Value Loss: 0.0000
# Triple Episode 482/500
# Policy Loss: 0.0013
# Policy Loss: 0.0011
# Policy Loss: 0.0011
# Policy Loss: 0.0011
# Policy Loss: 0.0011
# Triple Value Loss: 0.0000
# Triple Episode 483/500
# Policy Loss: 0.0029
# Policy Loss: 0.0026
# Policy Loss: 0.0026
# Policy Loss: 0.0026
# Policy Loss: 0.0026
# Triple Value Loss: 0.0000
# Triple Episode 484/500
# Policy Loss: -0.0006
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Policy Loss: -0.0007
# Triple Value Loss: 0.0000
# Triple Episode 485/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Policy Loss: -0.0005
# Triple Value Loss: 0.0000
# Triple Episode 486/500
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Triple Value Loss: 0.0000
# Triple Episode 487/500
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Policy Loss: -0.0008
# Triple Value Loss: 0.0000
# Triple Episode 488/500
# Policy Loss: -0.0019
# Policy Loss: -0.0021
# Policy Loss: -0.0021
# Policy Loss: -0.0021
# Policy Loss: -0.0021
# Triple Value Loss: 0.0000
# Triple Episode 489/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0007
# Policy Loss: 0.0007
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Policy Loss: 0.0006
# Triple Value Loss: 0.0000
# Triple Episode 490/500
# Policy Loss: 0.0003
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Triple Value Loss: 0.0000
# Triple Episode 491/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 492/500
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Policy Loss: 0.0001
# Triple Value Loss: 0.0000
# Triple Episode 493/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0009
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Triple Value Loss: 0.0000
# Triple Episode 494/500
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Triple Value Loss: 0.0000
# Triple Episode 495/500
# Policy Loss: 0.0003
# Policy Loss: 0.0003
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Policy Loss: 0.0002
# Triple Value Loss: 0.0000
# Triple Episode 496/500
# Task: triple, Reward: 0.0000
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Policy Loss: 0.0008
# Triple Value Loss: 0.0000
# Triple Episode 497/500
# Task: triple, Reward: 0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Policy Loss: -0.0000
# Triple Value Loss: 0.0000
# Triple Episode 498/500
# Policy Loss: 0.0010
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Policy Loss: 0.0009
# Triple Value Loss: 0.0000
# Triple Episode 499/500
# Policy Loss: 0.0013
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Policy Loss: 0.0012
# Triple Value Loss: 0.0000
# Triple Episode 500/500
# Task: triple, Reward: 0.0000
# Policy Loss: 0.0014
# Policy Loss: 0.0013
# Policy Loss: 0.0013
# Policy Loss: 0.0013
# Policy Loss: 0.0013
# Triple Value Loss: 0.0000
# Saved RL fine-tuned DPR models for triple task.

# %%
# Save RL Metrics and Artifacts

rl_metrics = {
    "qa_policy_losses": [],  # Placeholder, as losses are not computed in the current setup
    "qa_value_losses": [],   # Placeholder
    "triple_policy_losses": [],  # Placeholder
    "triple_value_losses": []    # Placeholder
}

rl_metrics_path = os.path.join(CONFIG.BASE_PATH, "rl_metrics_v4.json")
with open(rl_metrics_path, "w") as f:
    json.dump(rl_metrics, f)
print(f"Saved RL metrics at {rl_metrics_path}")

# Save updated candidate embeddings
with torch.no_grad():
    # Limit candidate pool size for faster encoding
    eval_candidates = all_candidates[:1000]  # Limit to 1000 candidates
    candidate_inputs = ctx_tokenizer(eval_candidates, return_tensors="pt", padding=True, truncation=True, max_length=CONFIG.MAX_LENGTH)
    candidate_inputs = {k: v.to(CONFIG.DEVICE) for k, v in candidate_inputs.items()}
    candidate_embeddings_qa = ctx_encoder_qa(**candidate_inputs).pooler_output
    candidate_embeddings_triple = ctx_encoder_triple(**candidate_inputs).pooler_output
torch.save(candidate_embeddings_qa, os.path.join(save_path, 'dpr_candidate_embeddings_rl_qa_v4.pt'))
torch.save(candidate_embeddings_triple, os.path.join(save_path, 'dpr_candidate_embeddings_rl_triple_v4.pt'))

print("Updated candidate embeddings saved for Version 4.")
# Out:
# Saved RL metrics at /content/drive/MyDrive/LJMU-Datasets/rl_metrics_v4.json
# Updated candidate embeddings saved for Version 4.

# %% [markdown]
# Improve RL reward

# %%
# Define RL Helper Functions

# Normalize text for evaluation
def normalize_text(text: str) -> str:
    text = str(text).lower().strip()
    text = text.translate(str.maketrans("", "", string.punctuation))
    articles = {'a', 'an', 'the'}
    words = text.split()
    words = [word for word in words if word not in articles]
    return ' '.join(words)

# Compute BLEU score
def compute_bleu(generated: str, reference: str) -> float:
    return sentence_bleu([reference.split()], generated.split())

# Compute ROUGE-L score
def compute_rouge_l(generated: str, reference: str) -> float:
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    return scorer.score(reference, generated)['rougeL'].fmeasure

# Compute BERTScore
def compute_bertscore(generated: str, reference: str) -> float:
    return bert_score.score([generated], [reference], lang="en", verbose=False)[2].mean().item()

# Compute MRR for reward
def compute_mrr(generated_ranking: torch.Tensor, ref_idx: int) -> float:
    rank = (generated_ranking == ref_idx).nonzero(as_tuple=True)[0].item() + 1 if ref_idx in generated_ranking else len(generated_ranking)
    return 1.0 / rank

# Compute reward for RL (Updated with semantic similarity for missing references)
def compute_reward(generated_ranking: torch.Tensor, reference: str) -> float:
    candidates = all_candidates[:100]  # Use small candidate pool for efficiency
    ref_idx = candidates.index(reference) if reference in candidates else -1
    if ref_idx == -1:
        # Compute semantic similarity to the reference using SentenceTransformer
        sentence_transformer = SentenceTransformer('all-MiniLM-L6-v2')
        ref_embedding = sentence_transformer.encode(reference, convert_to_tensor=True).to(CONFIG.DEVICE)
        candidate_embeddings = sentence_transformer.encode(candidates, convert_to_tensor=True).to(CONFIG.DEVICE)
        similarities = torch.cosine_similarity(ref_embedding.unsqueeze(0), candidate_embeddings, dim=1)
        max_similarity = similarities.max().item()
        # Scale the penalty based on the maximum similarity (closer to 0 if similar, closer to -0.5 if dissimilar)
        penalty = -0.5 * (1.0 - max_similarity)
        return penalty
    mrr = compute_mrr(generated_ranking, ref_idx)
    mrr_scaled = mrr * 2.0  # Scale MRR to provide stronger signal
    exact_match_bonus = 0.5 if generated_ranking[0] == ref_idx else 0.0
    exploration_bonus = 0.01  # Small bonus to encourage exploration
    return mrr_scaled + exact_match_bonus + exploration_bonus

# Policy Network for DPR (simple MLP to adjust embeddings)
class PolicyNetwork(torch.nn.Module):
    def __init__(self, input_dim=768, hidden_dim=256):
        super(PolicyNetwork, self).__init__()
        self.network = torch.nn.Sequential(
            torch.nn.Linear(input_dim, hidden_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_dim, input_dim),
            torch.nn.Tanh()  # Output adjustment to [-1, 1]
        )

    def forward(self, x):
        return self.network(x)

# RL Environment for DPR ranking
class RankingEnvironment:
    def __init__(self, ctx_encoder, question_encoder, candidates, candidate_embeddings, val_loader, task: str = "qa"):
        self.ctx_encoder = ctx_encoder
        self.question_encoder = question_encoder
        self.candidates = candidates
        self.candidate_embeddings = candidate_embeddings
        self.val_loader = val_loader
        self.task = task
        self.current_batch = None
        self.current_idx = 0
        self.batch_iterator = iter(val_loader)

    def reset(self):
        try:
            self.current_batch = next(self.batch_iterator)
            self.current_idx = 0
        except StopIteration:
            self.batch_iterator = iter(self.val_loader)
            self.current_batch = next(self.batch_iterator)
            self.current_idx = 0
        question_inputs = {
            "input_ids": self.current_batch["dpr_input_ids"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0),
            "attention_mask": self.current_batch["dpr_attention_mask"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0)
        }
        with torch.no_grad():
            state = self.question_encoder(**question_inputs).pooler_output  # Shape: (1, 768)
        return state

    def step(self, action):
        question_inputs = {
            "input_ids": self.current_batch["dpr_input_ids"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0),
            "attention_mask": self.current_batch["dpr_attention_mask"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0)
        }
        with torch.no_grad():
            question_embedding = self.question_encoder(**question_inputs).pooler_output  # Shape: (1, 768)
        adjusted_embedding = question_embedding + action  # Adjust embedding
        similarities = torch.matmul(adjusted_embedding, self.candidate_embeddings.T)  # Shape: (1, num_candidates)
        rankings = torch.argsort(similarities, dim=1, descending=True)
        ref = self.current_batch["answer"][self.current_idx]
        done = False
        reward = compute_reward(rankings[0].cpu(), ref)
        print(f"Task: {self.task}, Reward: {reward:.4f}")

        # Move to next sample
        self.current_idx += 1
        if self.current_idx >= len(self.current_batch["answer"]):
            try:
                self.current_batch = next(self.batch_iterator)
                self.current_idx = 0
            except StopIteration:
                done = True

        # Get next state
        if not done:
            next_question_inputs = {
                "input_ids": self.current_batch["dpr_input_ids"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0),
                "attention_mask": self.current_batch["dpr_attention_mask"][self.current_idx].to(CONFIG.DEVICE).unsqueeze(0)
            }
            with torch.no_grad():
                next_state = self.question_encoder(**next_question_inputs).pooler_output
        else:
            next_state = None

        return next_state, reward, done

# PPO Implementation
def compute_gae(rewards, values, next_value, gamma=0.99, lam=0.95):
    advantages = []
    gae = 0
    rewards = rewards + [next_value]
    values = values + [next_value]
    for t in reversed(range(len(rewards) - 1)):
        delta = rewards[t] + gamma * values[t + 1] - values[t]
        gae = delta + gamma * lam * gae
        advantages.insert(0, gae)
    return advantages

def ppo_update(policy, optimizer, states, actions, old_log_probs, advantages, returns, clip_epsilon=0.1, epochs=5):
    for _ in range(epochs):
        policy.train()
        new_log_probs = []
        for state, action in zip(states, actions):
            state = state.to(CONFIG.DEVICE)
            action = action.to(CONFIG.DEVICE)
            adjustment = policy(state)
            dist = torch.distributions.Normal(adjustment, 0.1)
            log_prob = dist.log_prob(action).sum(dim=-1)
            new_log_probs.append(log_prob)
        new_log_probs = torch.stack(new_log_probs)

        # Compute ratio
        ratios = torch.exp(new_log_probs - torch.stack(old_log_probs))

        # Compute surrogate loss
        surr1 = ratios * torch.tensor(advantages, device=CONFIG.DEVICE)
        surr2 = torch.clamp(ratios, 1 - clip_epsilon, 1 + clip_epsilon) * torch.tensor(advantages, device=CONFIG.DEVICE)
        policy_loss = -torch.min(surr1, surr2).mean()

        # Update policy
        optimizer.zero_grad()
        policy_loss.backward()
        optimizer.step()
        print(f"Policy Loss: {policy_loss.item():.4f}")

    return policy_loss.item()

print("RL helper functions defined.")
# Out:
# RL helper functions defined.

# %%
# Test Updated Reward Function and Re-Run RL Fine-Tuning for Triple Task

# Test the updated reward function on a few examples from triple data with a larger candidate pool
print("Testing updated reward function on triple data...")
val_batch = next(iter(triple_val_loader_v4))
test_references = val_batch["answer"][:5]
question_inputs = {
    "input_ids": val_batch["dpr_input_ids"][:5].to(CONFIG.DEVICE),
    "attention_mask": val_batch["dpr_attention_mask"][:5].to(CONFIG.DEVICE)
}
with torch.no_grad():
    question_embeddings = question_encoder_triple(**question_inputs).pooler_output
    similarities = torch.matmul(question_embeddings, candidate_embeddings_triple.T)
    rankings = torch.argsort(similarities, dim=1, descending=True).cpu()

# Temporarily increase candidate pool for testing
candidates = all_candidates[:500]  # Increase to 500 candidates for testing
for rank, ref in zip(rankings, test_references):
    reward = compute_reward(rank, ref)
    print(f"Reference: {ref}, Reward: {reward:.4f}")

# Re-run RL fine-tuning for the triple task with the updated reward function
policy_triple = PolicyNetwork(input_dim=768, hidden_dim=256).to(CONFIG.DEVICE)
value_network_triple = PolicyNetwork(input_dim=768, hidden_dim=256).to(CONFIG.DEVICE)
policy_optimizer_triple = torch.optim.Adam(policy_triple.parameters(), lr=5e-5)
value_optimizer_triple = torch.optim.Adam(value_network_triple.parameters(), lr=5e-5)

# Create environment for triple task
triple_env = RankingEnvironment(ctx_encoder_triple, question_encoder_triple, all_candidates, candidate_embeddings_triple, triple_val_loader_v4, task="triple")

num_episodes = 500
max_steps_per_episode = 50

print("Re-running fine-tuning DPR with PPO on triple data...")
triple_policy_losses = []
triple_value_losses = []
for episode in range(num_episodes):
    print(f"Triple Episode {episode + 1}/{num_episodes}")
    state = triple_env.reset()
    if state.dim() == 1:
        state = state.unsqueeze(0)
    states, actions, rewards, old_log_probs, values = [], [], [], [], []
    done = False
    episode_steps = 0

    while not done and episode_steps < max_steps_per_episode:
        state = state.to(CONFIG.DEVICE)
        with torch.no_grad():
            adjustment = policy_triple(state)
            dist = torch.distributions.Normal(adjustment, 0.1)
            action = dist.sample()
            log_prob = dist.log_prob(action).sum(dim=-1)
            value = value_network_triple(state).mean()

        next_state, reward, done = triple_env.step(action)

        if next_state is not None and next_state.dim() == 1:
            next_state = next_state.unsqueeze(0)

        states.append(state)
        actions.append(action)
        rewards.append(reward)
        old_log_probs.append(log_prob)
        values.append(value.item())

        state = next_state
        episode_steps += 1

    # Compute returns and advantages
    with torch.no_grad():
        next_value = value_network_triple(state).mean().item() if state is not None else 0.0
    advantages = compute_gae(rewards, values, next_value)
    returns = [r + next_value for r in rewards]

    # Update policy and value network
    policy_loss = ppo_update(policy_triple, policy_optimizer_triple, states, actions, old_log_probs, advantages, returns)
    triple_policy_losses.append(policy_loss)

    # Update value network
    value_loss = 0
    for state, ret in zip(states, returns):
        state = state.to(CONFIG.DEVICE)
        value = value_network_triple(state).mean()
        value_loss += (value - ret) ** 2
    value_loss = value_loss / len(states)
    value_optimizer_triple.zero_grad()
    value_loss.backward()
    value_optimizer_triple.step()
    triple_value_losses.append(value_loss.item())
    print(f"Triple Value Loss: {value_loss.item():.4f}")

# Save fine-tuned DPR models for triple task
ctx_encoder_triple.save_pretrained(os.path.join(CONFIG.BASE_PATH, "dpr_ctx_encoder_rl_triple_v4"))
question_encoder_triple.save_pretrained(os.path.join(CONFIG.BASE_PATH, "dpr_question_encoder_rl_triple_v4"))
print("Saved RL fine-tuned DPR models for triple task.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Task: triple, Reward: -0.2180
# Task: triple, Reward: -0.3029
# Task: triple, Reward: -0.2903
# Task: triple, Reward: -0.2666
# Task: triple, Reward: -0.2686
# Task: triple, Reward: -0.2615
# Task: triple, Reward: -0.3085
# Task: triple, Reward: -0.2847
# Policy Loss: 2.8493
# Policy Loss: 2.5643
# Policy Loss: 2.5643
# Policy Loss: 2.5643
# Policy Loss: 2.5643
# Triple Value Loss: 0.0624
# Triple Episode 413/500
# Task: triple, Reward: -0.3164
# Task: triple, Reward: -0.2176
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.4137
# Task: triple, Reward: -0.2231
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2571
# Task: triple, Reward: -0.1791
# Task: triple, Reward: -0.3133
# Task: triple, Reward: -0.2240
# Task: triple, Reward: -0.3104
# Task: triple, Reward: -0.2180
# Task: triple, Reward: -0.2472
# Task: triple, Reward: -0.2775
# Task: triple, Reward: -0.2403
# Task: triple, Reward: -0.2100
# Task: triple, Reward: -0.1730
# Task: triple, Reward: -0.1155
# Task: triple, Reward: 0.0143
# Task: triple, Reward: -0.2204
# Task: triple, Reward: -0.2298
# Task: triple, Reward: -0.2743
# Task: triple, Reward: -0.2356
# Task: triple, Reward: -0.3224
# Task: triple, Reward: -0.1859
# Task: triple, Reward: 0.0302
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2583
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.2730
# Task: triple, Reward: -0.2219
# Task: triple, Reward: -0.3216
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2683
# Task: triple, Reward: -0.2572
# Task: triple, Reward: -0.2656
# Task: triple, Reward: -0.1790
# Task: triple, Reward: -0.1419
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2877
# Task: triple, Reward: -0.2991
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2573
# Task: triple, Reward: -0.2602
# Task: triple, Reward: -0.2894
# Task: triple, Reward: -0.2085
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2172
# Policy Loss: 2.5232
# Policy Loss: 2.2709
# Policy Loss: 2.2709
# Policy Loss: 2.2709
# Policy Loss: 2.2709
# Triple Value Loss: 0.0580
# Triple Episode 414/500
# Task: triple, Reward: -0.1695
# Task: triple, Reward: -0.2303
# Task: triple, Reward: -0.2821
# Task: triple, Reward: -0.1735
# Task: triple, Reward: -0.2708
# Task: triple, Reward: -0.3888
# Task: triple, Reward: -0.2351
# Task: triple, Reward: -0.2333
# Task: triple, Reward: -0.2646
# Task: triple, Reward: -0.2108
# Task: triple, Reward: -0.2966
# Task: triple, Reward: -0.3275
# Task: triple, Reward: -0.2675
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.1908
# Task: triple, Reward: -0.3330
# Task: triple, Reward: -0.2514
# Task: triple, Reward: 0.0814
# Task: triple, Reward: -0.1878
# Task: triple, Reward: -0.2538
# Task: triple, Reward: -0.3078
# Task: triple, Reward: -0.1963
# Task: triple, Reward: -0.3173
# Task: triple, Reward: -0.1633
# Task: triple, Reward: -0.2868
# Task: triple, Reward: -0.1416
# Task: triple, Reward: -0.2482
# Task: triple, Reward: -0.2560
# Task: triple, Reward: -0.2005
# Task: triple, Reward: -0.1583
# Task: triple, Reward: -0.2807
# Task: triple, Reward: -0.3050
# Task: triple, Reward: -0.1973
# Task: triple, Reward: -0.2990
# Task: triple, Reward: -0.2274
# Task: triple, Reward: -0.2741
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2758
# Task: triple, Reward: -0.2650
# Task: triple, Reward: -0.2307
# Task: triple, Reward: -0.1876
# Task: triple, Reward: -0.1332
# Task: triple, Reward: -0.2772
# Task: triple, Reward: -0.2303
# Task: triple, Reward: -0.2185
# Task: triple, Reward: -0.2100
# Task: triple, Reward: -0.2656
# Task: triple, Reward: -0.3015
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.2317
# Policy Loss: 2.6217
# Policy Loss: 2.3596
# Policy Loss: 2.3596
# Policy Loss: 2.3596
# Policy Loss: 2.3596
# Triple Value Loss: 0.0607
# Triple Episode 415/500
# Task: triple, Reward: -0.2894
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.2193
# Task: triple, Reward: -0.2331
# Task: triple, Reward: -0.2653
# Task: triple, Reward: -0.2509
# Task: triple, Reward: -0.2250
# Task: triple, Reward: -0.2290
# Task: triple, Reward: -0.2253
# Task: triple, Reward: 0.0526
# Task: triple, Reward: -0.1912
# Task: triple, Reward: -0.3012
# Task: triple, Reward: -0.3037
# Task: triple, Reward: -0.2647
# Task: triple, Reward: -0.1670
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.2919
# Task: triple, Reward: -0.3608
# Task: triple, Reward: -0.2376
# Task: triple, Reward: 0.0588
# Task: triple, Reward: -0.2181
# Task: triple, Reward: -0.3104
# Task: triple, Reward: -0.2326
# Task: triple, Reward: -0.2937
# Task: triple, Reward: -0.2349
# Task: triple, Reward: -0.3109
# Task: triple, Reward: -0.3005
# Task: triple, Reward: -0.2488
# Task: triple, Reward: -0.2591
# Task: triple, Reward: -0.2526
# Task: triple, Reward: -0.2297
# Task: triple, Reward: -0.2329
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.3339
# Task: triple, Reward: -0.2270
# Task: triple, Reward: -0.2383
# Task: triple, Reward: -0.2483
# Task: triple, Reward: -0.2619
# Task: triple, Reward: -0.1981
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.2753
# Task: triple, Reward: -0.2820
# Task: triple, Reward: -0.2918
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2984
# Task: triple, Reward: -0.2322
# Policy Loss: 2.7334
# Policy Loss: 2.4600
# Policy Loss: 2.4600
# Policy Loss: 2.4600
# Policy Loss: 2.4600
# Triple Value Loss: 0.0621
# Triple Episode 416/500
# Task: triple, Reward: -0.1670
# Task: triple, Reward: -0.2573
# Task: triple, Reward: -0.1941
# Task: triple, Reward: -0.2363
# Task: triple, Reward: 0.0185
# Task: triple, Reward: -0.2025
# Task: triple, Reward: -0.2219
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.2832
# Task: triple, Reward: -0.2682
# Task: triple, Reward: -0.3009
# Task: triple, Reward: -0.2574
# Task: triple, Reward: -0.2937
# Task: triple, Reward: -0.3268
# Task: triple, Reward: -0.2201
# Task: triple, Reward: -0.2636
# Task: triple, Reward: -0.1427
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2688
# Task: triple, Reward: -0.2064
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2597
# Task: triple, Reward: -0.2676
# Task: triple, Reward: -0.2510
# Task: triple, Reward: -0.2326
# Task: triple, Reward: -0.1790
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2896
# Task: triple, Reward: -0.2383
# Task: triple, Reward: 0.0333
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.1987
# Task: triple, Reward: -0.2759
# Task: triple, Reward: -0.3219
# Task: triple, Reward: -0.2823
# Task: triple, Reward: -0.2785
# Task: triple, Reward: -0.3047
# Task: triple, Reward: -0.3543
# Task: triple, Reward: -0.2703
# Task: triple, Reward: -0.2807
# Task: triple, Reward: -0.2209
# Task: triple, Reward: -0.2860
# Task: triple, Reward: -0.2967
# Task: triple, Reward: -0.2085
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.2688
# Task: triple, Reward: -0.3125
# Task: triple, Reward: -0.2397
# Task: triple, Reward: -0.2219
# Task: triple, Reward: -0.2318
# Policy Loss: 2.7444
# Policy Loss: 2.4700
# Policy Loss: 2.4700
# Policy Loss: 2.4700
# Policy Loss: 2.4700
# Triple Value Loss: 0.0622
# Triple Episode 417/500
# Task: triple, Reward: -0.1988
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.2544
# Task: triple, Reward: -0.1858
# Task: triple, Reward: -0.2713
# Task: triple, Reward: -0.2694
# Task: triple, Reward: -0.1923
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2338
# Task: triple, Reward: -0.2993
# Task: triple, Reward: -0.2993
# Task: triple, Reward: -0.1973
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2326
# Task: triple, Reward: -0.1638
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2649
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.2573
# Task: triple, Reward: 0.0790
# Task: triple, Reward: -0.2213
# Task: triple, Reward: 0.0140
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2337
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.2919
# Task: triple, Reward: -0.2102
# Task: triple, Reward: -0.2212
# Task: triple, Reward: -0.3464
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.3202
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2842
# Task: triple, Reward: -0.2126
# Task: triple, Reward: -0.2159
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.2416
# Task: triple, Reward: 0.0500
# Task: triple, Reward: -0.2219
# Task: triple, Reward: -0.3495
# Task: triple, Reward: -0.3005
# Task: triple, Reward: -0.2926
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2088
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.2428
# Task: triple, Reward: -0.2070
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2946
# Task: triple, Reward: -0.2310
# Policy Loss: 2.4784
# Policy Loss: 2.2306
# Policy Loss: 2.2306
# Policy Loss: 2.2306
# Policy Loss: 2.2306
# Triple Value Loss: 0.0553
# Triple Episode 418/500
# Task: triple, Reward: -0.2594
# Task: triple, Reward: -0.2847
# Task: triple, Reward: 0.0138
# Task: triple, Reward: -0.2344
# Task: triple, Reward: -0.2220
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.3011
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.2689
# Task: triple, Reward: -0.2349
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2005
# Task: triple, Reward: -0.2339
# Task: triple, Reward: -0.3179
# Task: triple, Reward: -0.2712
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2159
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2811
# Task: triple, Reward: -0.2510
# Task: triple, Reward: -0.3561
# Task: triple, Reward: -0.3140
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.3324
# Task: triple, Reward: -0.2170
# Task: triple, Reward: -0.1667
# Task: triple, Reward: -0.3061
# Task: triple, Reward: -0.2439
# Task: triple, Reward: -0.3270
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2877
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.3087
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.1849
# Task: triple, Reward: -0.3227
# Task: triple, Reward: -0.2877
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.2930
# Task: triple, Reward: -0.2764
# Task: triple, Reward: -0.1987
# Task: triple, Reward: -0.2770
# Task: triple, Reward: -0.2874
# Task: triple, Reward: -0.2347
# Task: triple, Reward: -0.1790
# Task: triple, Reward: -0.3112
# Task: triple, Reward: -0.1790
# Task: triple, Reward: -0.2058
# Policy Loss: 2.7947
# Policy Loss: 2.5152
# Policy Loss: 2.5152
# Policy Loss: 2.5152
# Policy Loss: 2.5152
# Triple Value Loss: 0.0647
# Triple Episode 419/500
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2407
# Task: triple, Reward: -0.2783
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2479
# Task: triple, Reward: -0.2814
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.2248
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.1639
# Task: triple, Reward: -0.1622
# Task: triple, Reward: -0.3119
# Task: triple, Reward: -0.2146
# Task: triple, Reward: -0.2805
# Task: triple, Reward: -0.2902
# Task: triple, Reward: -0.2570
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.3118
# Task: triple, Reward: -0.2507
# Task: triple, Reward: -0.2697
# Task: triple, Reward: -0.3035
# Task: triple, Reward: -0.2897
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.2465
# Task: triple, Reward: -0.2937
# Task: triple, Reward: -0.2828
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2562
# Task: triple, Reward: -0.3090
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.2945
# Task: triple, Reward: -0.2586
# Task: triple, Reward: -0.3150
# Task: triple, Reward: -0.2363
# Task: triple, Reward: -0.1332
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2185
# Task: triple, Reward: -0.2339
# Task: triple, Reward: -0.3289
# Task: triple, Reward: -0.2762
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2107
# Task: triple, Reward: -0.3136
# Task: triple, Reward: -0.1987
# Task: triple, Reward: -0.1982
# Task: triple, Reward: -0.3134
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.1825
# Task: triple, Reward: -0.1569
# Policy Loss: 2.7633
# Policy Loss: 2.4870
# Policy Loss: 2.4870
# Policy Loss: 2.4870
# Policy Loss: 2.4870
# Triple Value Loss: 0.0618
# Triple Episode 420/500
# Task: triple, Reward: -0.1975
# Task: triple, Reward: -0.3341
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2842
# Task: triple, Reward: -0.2173
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.3123
# Task: triple, Reward: -0.3218
# Task: triple, Reward: -0.2365
# Task: triple, Reward: -0.2094
# Task: triple, Reward: -0.2392
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.2311
# Task: triple, Reward: -0.2370
# Task: triple, Reward: -0.2290
# Task: triple, Reward: -0.2400
# Task: triple, Reward: -0.2250
# Task: triple, Reward: -0.2955
# Task: triple, Reward: -0.3051
# Task: triple, Reward: -0.2528
# Task: triple, Reward: -0.2917
# Task: triple, Reward: -0.1427
# Task: triple, Reward: -0.2107
# Task: triple, Reward: -0.1840
# Task: triple, Reward: -0.2428
# Task: triple, Reward: -0.2865
# Task: triple, Reward: -0.2473
# Task: triple, Reward: -0.2993
# Task: triple, Reward: -0.2747
# Task: triple, Reward: -0.2403
# Task: triple, Reward: -0.1639
# Task: triple, Reward: -0.3005
# Task: triple, Reward: -0.1786
# Task: triple, Reward: -0.2064
# Task: triple, Reward: -0.2428
# Task: triple, Reward: 0.0245
# Task: triple, Reward: -0.2968
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.1923
# Task: triple, Reward: 0.0613
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.3073
# Task: triple, Reward: -0.3275
# Task: triple, Reward: -0.2613
# Task: triple, Reward: -0.2565
# Task: triple, Reward: -0.2335
# Task: triple, Reward: -0.2651
# Task: triple, Reward: -0.2013
# Policy Loss: 2.5535
# Policy Loss: 2.2982
# Policy Loss: 2.2982
# Policy Loss: 2.2982
# Policy Loss: 2.2982
# Triple Value Loss: 0.0596
# Triple Episode 421/500
# Task: triple, Reward: -0.3115
# Task: triple, Reward: -0.2869
# Task: triple, Reward: -0.2243
# Task: triple, Reward: -0.2185
# Task: triple, Reward: -0.3391
# Task: triple, Reward: -0.3376
# Task: triple, Reward: -0.2618
# Task: triple, Reward: -0.2922
# Task: triple, Reward: -0.3006
# Task: triple, Reward: -0.1914
# Task: triple, Reward: -0.2782
# Task: triple, Reward: -0.1967
# Task: triple, Reward: -0.3320
# Task: triple, Reward: -0.3339
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2741
# Task: triple, Reward: -0.2638
# Task: triple, Reward: -0.2927
# Task: triple, Reward: -0.0962
# Task: triple, Reward: -0.2212
# Task: triple, Reward: -0.2279
# Task: triple, Reward: -0.2618
# Task: triple, Reward: -0.1908
# Task: triple, Reward: -0.2368
# Task: triple, Reward: -0.2562
# Task: triple, Reward: -0.2194
# Task: triple, Reward: -0.1982
# Task: triple, Reward: -0.2575
# Task: triple, Reward: -0.2734
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.3051
# Task: triple, Reward: -0.2527
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2135
# Task: triple, Reward: -0.2819
# Task: triple, Reward: -0.2993
# Task: triple, Reward: -0.3347
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.2155
# Task: triple, Reward: -0.1859
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2329
# Task: triple, Reward: -0.2614
# Task: triple, Reward: -0.3510
# Task: triple, Reward: -0.2506
# Task: triple, Reward: -0.3012
# Task: triple, Reward: -0.2883
# Task: triple, Reward: -0.2352
# Task: triple, Reward: -0.2767
# Policy Loss: 2.7996
# Policy Loss: 2.5197
# Policy Loss: 2.5197
# Policy Loss: 2.5197
# Policy Loss: 2.5197
# Triple Value Loss: 0.0672
# Triple Episode 422/500
# Task: triple, Reward: -0.2759
# Task: triple, Reward: -0.2721
# Task: triple, Reward: -0.2362
# Task: triple, Reward: -0.3227
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.2483
# Task: triple, Reward: -0.3183
# Task: triple, Reward: -0.2752
# Task: triple, Reward: -0.2048
# Task: triple, Reward: -0.2253
# Task: triple, Reward: 0.0155
# Task: triple, Reward: -0.2212
# Task: triple, Reward: 0.0210
# Task: triple, Reward: -0.2744
# Task: triple, Reward: 0.0157
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.2180
# Task: triple, Reward: -0.1735
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2950
# Task: triple, Reward: -0.2194
# Task: triple, Reward: -0.2772
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2729
# Task: triple, Reward: -0.2346
# Task: triple, Reward: -0.2931
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2510
# Task: triple, Reward: -0.2573
# Task: triple, Reward: -0.2961
# Task: triple, Reward: -0.1433
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2602
# Task: triple, Reward: -0.2070
# Task: triple, Reward: -0.2662
# Task: triple, Reward: -0.3434
# Task: triple, Reward: -0.2570
# Task: triple, Reward: 0.2600
# Task: triple, Reward: -0.3030
# Task: triple, Reward: -0.1988
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2536
# Task: triple, Reward: -0.2930
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2123
# Task: triple, Reward: -0.2955
# Task: triple, Reward: -0.2299
# Task: triple, Reward: -0.2669
# Task: triple, Reward: -0.2905
# Task: triple, Reward: -0.2510
# Policy Loss: 2.4940
# Policy Loss: 2.2448
# Policy Loss: 2.2446
# Policy Loss: 2.2446
# Policy Loss: 2.2446
# Triple Value Loss: 0.0604
# Triple Episode 423/500
# Task: triple, Reward: -0.2530
# Task: triple, Reward: -0.3211
# Task: triple, Reward: -0.2708
# Task: triple, Reward: 0.0143
# Task: triple, Reward: -0.2619
# Task: triple, Reward: -0.3393
# Task: triple, Reward: -0.1859
# Task: triple, Reward: -0.2346
# Task: triple, Reward: -0.2016
# Task: triple, Reward: -0.2810
# Task: triple, Reward: -0.2858
# Task: triple, Reward: -0.2605
# Task: triple, Reward: -0.3355
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.2111
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2212
# Task: triple, Reward: -0.2455
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.2635
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.3002
# Task: triple, Reward: -0.2678
# Task: triple, Reward: -0.2383
# Task: triple, Reward: -0.2216
# Task: triple, Reward: -0.2536
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2636
# Task: triple, Reward: -0.2651
# Task: triple, Reward: -0.2301
# Task: triple, Reward: 0.0279
# Task: triple, Reward: -0.2030
# Task: triple, Reward: -0.2185
# Task: triple, Reward: -0.2335
# Task: triple, Reward: -0.2390
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.3435
# Task: triple, Reward: -0.2675
# Task: triple, Reward: -0.3163
# Task: triple, Reward: -0.2608
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2958
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.2064
# Task: triple, Reward: -0.2673
# Task: triple, Reward: -0.2678
# Task: triple, Reward: -0.2243
# Task: triple, Reward: -0.2993
# Task: triple, Reward: -0.2683
# Task: triple, Reward: 0.0143
# Policy Loss: 2.6273
# Policy Loss: 2.3649
# Policy Loss: 2.3648
# Policy Loss: 2.3648
# Policy Loss: 2.3648
# Triple Value Loss: 0.0622
# Triple Episode 424/500
# Task: triple, Reward: -0.2647
# Task: triple, Reward: -0.1919
# Task: triple, Reward: -0.1790
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2764
# Task: triple, Reward: -0.2438
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.3183
# Task: triple, Reward: -0.2344
# Task: triple, Reward: -0.2470
# Task: triple, Reward: -0.2853
# Task: triple, Reward: -0.1778
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2902
# Task: triple, Reward: -0.2687
# Task: triple, Reward: -0.2747
# Task: triple, Reward: -0.1923
# Task: triple, Reward: -0.2569
# Task: triple, Reward: -0.2883
# Task: triple, Reward: -0.3663
# Task: triple, Reward: -0.2651
# Task: triple, Reward: -0.2799
# Task: triple, Reward: -0.2687
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2512
# Task: triple, Reward: -0.2791
# Task: triple, Reward: -0.2428
# Task: triple, Reward: -0.2869
# Task: triple, Reward: -0.1667
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.2573
# Task: triple, Reward: -0.2612
# Task: triple, Reward: -0.2315
# Task: triple, Reward: -0.2814
# Task: triple, Reward: -0.3013
# Task: triple, Reward: -0.2451
# Task: triple, Reward: -0.2896
# Task: triple, Reward: -0.2146
# Task: triple, Reward: 0.0413
# Task: triple, Reward: -0.3028
# Task: triple, Reward: -0.2515
# Task: triple, Reward: -0.2830
# Task: triple, Reward: -0.2269
# Task: triple, Reward: -0.2623
# Task: triple, Reward: -0.2876
# Task: triple, Reward: -0.3122
# Task: triple, Reward: -0.2107
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.3699
# Task: triple, Reward: -0.2544
# Policy Loss: 2.8204
# Policy Loss: 2.5383
# Policy Loss: 2.5383
# Policy Loss: 2.5383
# Policy Loss: 2.5383
# Triple Value Loss: 0.0658
# Triple Episode 425/500
# Task: triple, Reward: -0.1923
# Task: triple, Reward: -0.1878
# Task: triple, Reward: -0.3241
# Task: triple, Reward: -0.2349
# Task: triple, Reward: -0.3023
# Task: triple, Reward: -0.2389
# Task: triple, Reward: -0.2993
# Task: triple, Reward: -0.2443
# Task: triple, Reward: -0.2024
# Task: triple, Reward: -0.2540
# Task: triple, Reward: -0.2279
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2515
# Task: triple, Reward: -0.2872
# Task: triple, Reward: -0.2651
# Task: triple, Reward: -0.2418
# Task: triple, Reward: -0.3211
# Task: triple, Reward: -0.2397
# Task: triple, Reward: 0.0149
# Task: triple, Reward: -0.1981
# Task: triple, Reward: -0.2048
# Task: triple, Reward: -0.2572
# Task: triple, Reward: -0.1730
# Task: triple, Reward: -0.3157
# Task: triple, Reward: -0.2194
# Task: triple, Reward: -0.1941
# Task: triple, Reward: -0.2194
# Task: triple, Reward: -0.2736
# Task: triple, Reward: -0.3379
# Task: triple, Reward: -0.2735
# Task: triple, Reward: -0.2243
# Task: triple, Reward: -0.2946
# Task: triple, Reward: -0.2250
# Task: triple, Reward: -0.2114
# Task: triple, Reward: -0.2737
# Task: triple, Reward: -0.2555
# Task: triple, Reward: -0.2219
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2500
# Task: triple, Reward: -0.1639
# Task: triple, Reward: -0.2538
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2955
# Task: triple, Reward: -0.2344
# Task: triple, Reward: -0.2310
# Task: triple, Reward: 2.5100
# Task: triple, Reward: -0.3405
# Task: triple, Reward: -0.2412
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.3239
# Policy Loss: 1.8282
# Policy Loss: 1.6702
# Policy Loss: 1.6906
# Policy Loss: 1.7033
# Policy Loss: 1.7114
# Triple Value Loss: 0.1855
# Triple Episode 426/500
# Task: triple, Reward: -0.2673
# Task: triple, Reward: -0.2545
# Task: triple, Reward: -0.3163
# Task: triple, Reward: -0.3032
# Task: triple, Reward: -0.1433
# Task: triple, Reward: -0.2643
# Task: triple, Reward: -0.3270
# Task: triple, Reward: 0.0215
# Task: triple, Reward: -0.2888
# Task: triple, Reward: -0.1767
# Task: triple, Reward: -0.2013
# Task: triple, Reward: -0.2159
# Task: triple, Reward: -0.2123
# Task: triple, Reward: -0.1973
# Task: triple, Reward: -0.3247
# Task: triple, Reward: -0.2833
# Task: triple, Reward: -0.2979
# Task: triple, Reward: -0.3446
# Task: triple, Reward: -0.1516
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.3692
# Task: triple, Reward: -0.1988
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.3340
# Task: triple, Reward: -0.3168
# Task: triple, Reward: -0.2671
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.2606
# Task: triple, Reward: -0.2261
# Task: triple, Reward: -0.1912
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.1767
# Task: triple, Reward: -0.2569
# Task: triple, Reward: -0.1332
# Task: triple, Reward: -0.3085
# Task: triple, Reward: -0.3006
# Task: triple, Reward: -0.3075
# Task: triple, Reward: -0.2864
# Task: triple, Reward: -0.2683
# Task: triple, Reward: 0.0158
# Task: triple, Reward: -0.3041
# Task: triple, Reward: -0.2361
# Task: triple, Reward: -0.2193
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.3221
# Task: triple, Reward: -0.2751
# Task: triple, Reward: -0.2397
# Task: triple, Reward: -0.2246
# Task: triple, Reward: -0.1791
# Task: triple, Reward: -0.2372
# Policy Loss: 2.6963
# Policy Loss: 2.4266
# Policy Loss: 2.4266
# Policy Loss: 2.4266
# Policy Loss: 2.4266
# Triple Value Loss: 0.0639
# Triple Episode 427/500
# Task: triple, Reward: -0.2412
# Task: triple, Reward: -0.2397
# Task: triple, Reward: -0.2888
# Task: triple, Reward: -0.1767
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.1775
# Task: triple, Reward: -0.2413
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2473
# Task: triple, Reward: -0.2578
# Task: triple, Reward: -0.2368
# Task: triple, Reward: -0.2679
# Task: triple, Reward: -0.2680
# Task: triple, Reward: -0.1923
# Task: triple, Reward: -0.1776
# Task: triple, Reward: -0.1878
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2662
# Task: triple, Reward: -0.2310
# Task: triple, Reward: 0.0500
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2510
# Task: triple, Reward: -0.1987
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.1796
# Task: triple, Reward: -0.2847
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.1639
# Task: triple, Reward: -0.1908
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2988
# Task: triple, Reward: -0.2452
# Task: triple, Reward: -0.1425
# Task: triple, Reward: -0.1638
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2269
# Task: triple, Reward: -0.2340
# Task: triple, Reward: -0.2605
# Task: triple, Reward: -0.3261
# Task: triple, Reward: -0.3020
# Task: triple, Reward: -0.1859
# Task: triple, Reward: 0.1529
# Task: triple, Reward: -0.3138
# Task: triple, Reward: -0.2289
# Task: triple, Reward: -0.2224
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.2715
# Task: triple, Reward: -0.3081
# Policy Loss: 2.4288
# Policy Loss: 2.1859
# Policy Loss: 2.1859
# Policy Loss: 2.1859
# Policy Loss: 2.1859
# Triple Value Loss: 0.0557
# Triple Episode 428/500
# Task: triple, Reward: 0.0320
# Task: triple, Reward: -0.2297
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.1639
# Task: triple, Reward: -0.2172
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2056
# Task: triple, Reward: -0.1791
# Task: triple, Reward: -0.2394
# Task: triple, Reward: -0.3109
# Task: triple, Reward: -0.2212
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.1774
# Task: triple, Reward: -0.2742
# Task: triple, Reward: -0.2673
# Task: triple, Reward: -0.2959
# Task: triple, Reward: -0.2195
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2220
# Task: triple, Reward: -0.2587
# Task: triple, Reward: -0.2765
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.1427
# Task: triple, Reward: -0.3295
# Task: triple, Reward: -0.2021
# Task: triple, Reward: -0.2379
# Task: triple, Reward: -0.3006
# Task: triple, Reward: -0.3184
# Task: triple, Reward: -0.2748
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.2404
# Task: triple, Reward: -0.1690
# Task: triple, Reward: -0.2161
# Task: triple, Reward: -0.2818
# Task: triple, Reward: -0.1943
# Task: triple, Reward: -0.2678
# Task: triple, Reward: -0.2395
# Task: triple, Reward: -0.2473
# Task: triple, Reward: -0.3099
# Task: triple, Reward: -0.2942
# Task: triple, Reward: -0.2591
# Task: triple, Reward: -0.3270
# Task: triple, Reward: -0.2085
# Task: triple, Reward: -0.2979
# Task: triple, Reward: -0.2219
# Task: triple, Reward: -0.2945
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.2126
# Task: triple, Reward: -0.2293
# Policy Loss: 2.7086
# Policy Loss: 2.4405
# Policy Loss: 2.4378
# Policy Loss: 2.4378
# Policy Loss: 2.4378
# Triple Value Loss: 0.0585
# Triple Episode 429/500
# Task: triple, Reward: -0.2086
# Task: triple, Reward: -0.1878
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2426
# Task: triple, Reward: -0.1920
# Task: triple, Reward: -0.1634
# Task: triple, Reward: -0.2146
# Task: triple, Reward: -0.2357
# Task: triple, Reward: -0.2917
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2433
# Task: triple, Reward: -0.2808
# Task: triple, Reward: -0.2172
# Task: triple, Reward: -0.2601
# Task: triple, Reward: -0.2773
# Task: triple, Reward: -0.2434
# Task: triple, Reward: -0.2924
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.1859
# Task: triple, Reward: -0.3356
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.2708
# Task: triple, Reward: -0.3499
# Task: triple, Reward: -0.2107
# Task: triple, Reward: -0.3339
# Task: triple, Reward: -0.2762
# Task: triple, Reward: 0.0671
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.1920
# Task: triple, Reward: -0.3480
# Task: triple, Reward: -0.2396
# Task: triple, Reward: -0.1746
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.2180
# Task: triple, Reward: -0.2611
# Task: triple, Reward: -0.3107
# Task: triple, Reward: -0.2491
# Task: triple, Reward: -0.2605
# Task: triple, Reward: -0.2395
# Task: triple, Reward: -0.3195
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.3096
# Task: triple, Reward: -0.1825
# Task: triple, Reward: -0.2176
# Task: triple, Reward: -0.1699
# Task: triple, Reward: -0.2368
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2578
# Task: triple, Reward: -0.2421
# Policy Loss: 2.6990
# Policy Loss: 2.4291
# Policy Loss: 2.4291
# Policy Loss: 2.4291
# Policy Loss: 2.4291
# Triple Value Loss: 0.0617
# Triple Episode 430/500
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.2820
# Task: triple, Reward: -0.2686
# Task: triple, Reward: -0.2552
# Task: triple, Reward: -0.3232
# Task: triple, Reward: -0.2878
# Task: triple, Reward: -0.3134
# Task: triple, Reward: -0.2497
# Task: triple, Reward: -0.2481
# Task: triple, Reward: -0.2929
# Task: triple, Reward: -0.2333
# Task: triple, Reward: -0.2453
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2791
# Task: triple, Reward: -0.1714
# Task: triple, Reward: -0.2204
# Task: triple, Reward: -0.1790
# Task: triple, Reward: -0.3343
# Task: triple, Reward: -0.2005
# Task: triple, Reward: -0.3403
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2991
# Task: triple, Reward: -0.2267
# Task: triple, Reward: 0.0155
# Task: triple, Reward: -0.1973
# Task: triple, Reward: -0.2193
# Task: triple, Reward: -0.2841
# Task: triple, Reward: -0.2689
# Task: triple, Reward: -0.2304
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.3075
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2150
# Task: triple, Reward: -0.2939
# Task: triple, Reward: 0.0417
# Task: triple, Reward: 0.0814
# Task: triple, Reward: -0.2352
# Task: triple, Reward: -0.2439
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.3323
# Task: triple, Reward: -0.2764
# Task: triple, Reward: -0.2391
# Task: triple, Reward: -0.2562
# Task: triple, Reward: -0.2283
# Task: triple, Reward: -0.3094
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.2953
# Task: triple, Reward: -0.1753
# Task: triple, Reward: -0.2692
# Policy Loss: 2.5298
# Policy Loss: 2.2768
# Policy Loss: 2.2768
# Policy Loss: 2.2768
# Policy Loss: 2.2768
# Triple Value Loss: 0.0594
# Triple Episode 431/500
# Task: triple, Reward: -0.1808
# Task: triple, Reward: -0.3270
# Task: triple, Reward: -0.2763
# Task: triple, Reward: -0.2326
# Task: triple, Reward: -0.3005
# Task: triple, Reward: -0.2870
# Task: triple, Reward: -0.2785
# Task: triple, Reward: -0.2180
# Task: triple, Reward: -0.2176
# Task: triple, Reward: -0.2346
# Task: triple, Reward: -0.2288
# Task: triple, Reward: -0.2491
# Task: triple, Reward: -0.2484
# Task: triple, Reward: -0.2884
# Task: triple, Reward: -0.3017
# Task: triple, Reward: -0.2146
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2675
# Task: triple, Reward: -0.2940
# Task: triple, Reward: -0.2877
# Task: triple, Reward: -0.3466
# Task: triple, Reward: 0.0212
# Task: triple, Reward: -0.2433
# Task: triple, Reward: -0.1717
# Task: triple, Reward: -0.2011
# Task: triple, Reward: -0.2159
# Task: triple, Reward: -0.2243
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.1923
# Task: triple, Reward: -0.2745
# Task: triple, Reward: -0.2220
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2088
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.1849
# Task: triple, Reward: -0.3025
# Task: triple, Reward: -0.2656
# Task: triple, Reward: -0.2573
# Task: triple, Reward: -0.2217
# Task: triple, Reward: -0.2636
# Task: triple, Reward: -0.2648
# Task: triple, Reward: -0.2064
# Task: triple, Reward: -0.2421
# Task: triple, Reward: -0.2059
# Task: triple, Reward: -0.2848
# Task: triple, Reward: -0.2891
# Task: triple, Reward: -0.2764
# Task: triple, Reward: -0.3153
# Task: triple, Reward: -0.2085
# Policy Loss: 2.7057
# Policy Loss: 2.4351
# Policy Loss: 2.4351
# Policy Loss: 2.4351
# Policy Loss: 2.4351
# Triple Value Loss: 0.0613
# Triple Episode 432/500
# Task: triple, Reward: -0.2270
# Task: triple, Reward: -0.2842
# Task: triple, Reward: -0.1774
# Task: triple, Reward: -0.2333
# Task: triple, Reward: -0.2473
# Task: triple, Reward: -0.2368
# Task: triple, Reward: -0.3025
# Task: triple, Reward: -0.3152
# Task: triple, Reward: -0.1427
# Task: triple, Reward: -0.3215
# Task: triple, Reward: -0.2317
# Task: triple, Reward: -0.2287
# Task: triple, Reward: -0.2675
# Task: triple, Reward: -0.2088
# Task: triple, Reward: -0.1981
# Task: triple, Reward: -0.2559
# Task: triple, Reward: 0.0315
# Task: triple, Reward: -0.2612
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.3648
# Task: triple, Reward: -0.2369
# Task: triple, Reward: -0.2166
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.2865
# Task: triple, Reward: -0.3184
# Task: triple, Reward: -0.3027
# Task: triple, Reward: -0.2259
# Task: triple, Reward: 0.1433
# Task: triple, Reward: -0.3147
# Task: triple, Reward: -0.2088
# Task: triple, Reward: 0.0159
# Task: triple, Reward: -0.2638
# Task: triple, Reward: -0.2204
# Task: triple, Reward: -0.2667
# Task: triple, Reward: -0.2572
# Task: triple, Reward: -0.3364
# Task: triple, Reward: -0.2472
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.2504
# Task: triple, Reward: -0.2484
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2339
# Task: triple, Reward: -0.2972
# Task: triple, Reward: -0.3040
# Task: triple, Reward: -0.1290
# Task: triple, Reward: -0.1981
# Task: triple, Reward: -0.2368
# Task: triple, Reward: 0.0274
# Task: triple, Reward: -0.2175
# Policy Loss: 2.4262
# Policy Loss: 2.1836
# Policy Loss: 2.1836
# Policy Loss: 2.1836
# Policy Loss: 2.1836
# Triple Value Loss: 0.0585
# Triple Episode 433/500
# Task: triple, Reward: -0.1923
# Task: triple, Reward: -0.2788
# Task: triple, Reward: -0.2307
# Task: triple, Reward: -0.3009
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2579
# Task: triple, Reward: -0.2703
# Task: triple, Reward: -0.2108
# Task: triple, Reward: -0.1634
# Task: triple, Reward: -0.2246
# Task: triple, Reward: -0.2646
# Task: triple, Reward: -0.2705
# Task: triple, Reward: 0.0333
# Task: triple, Reward: -0.3207
# Task: triple, Reward: -0.3052
# Task: triple, Reward: -0.2805
# Task: triple, Reward: -0.2825
# Task: triple, Reward: -0.2555
# Task: triple, Reward: -0.3129
# Task: triple, Reward: -0.3289
# Task: triple, Reward: -0.2671
# Task: triple, Reward: -0.1791
# Task: triple, Reward: -0.2764
# Task: triple, Reward: -0.2532
# Task: triple, Reward: -0.2764
# Task: triple, Reward: -0.2314
# Task: triple, Reward: -0.1885
# Task: triple, Reward: -0.2183
# Task: triple, Reward: -0.1332
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2752
# Task: triple, Reward: -0.3085
# Task: triple, Reward: -0.2317
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.2767
# Task: triple, Reward: -0.1973
# Task: triple, Reward: -0.2908
# Task: triple, Reward: -0.2064
# Task: triple, Reward: -0.2176
# Task: triple, Reward: -0.2140
# Task: triple, Reward: -0.1920
# Task: triple, Reward: -0.3244
# Task: triple, Reward: -0.3066
# Task: triple, Reward: -0.2575
# Task: triple, Reward: -0.2590
# Task: triple, Reward: -0.2115
# Task: triple, Reward: -0.2887
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.3154
# Task: triple, Reward: -0.1569
# Policy Loss: 2.7464
# Policy Loss: 2.4717
# Policy Loss: 2.4717
# Policy Loss: 2.4717
# Policy Loss: 2.4717
# Triple Value Loss: 0.0624
# Triple Episode 434/500
# Task: triple, Reward: -0.2094
# Task: triple, Reward: -0.3165
# Task: triple, Reward: -0.3098
# Task: triple, Reward: -0.2238
# Task: triple, Reward: -0.2085
# Task: triple, Reward: -0.2631
# Task: triple, Reward: -0.1639
# Task: triple, Reward: -0.3034
# Task: triple, Reward: -0.1775
# Task: triple, Reward: -0.2661
# Task: triple, Reward: -0.2070
# Task: triple, Reward: -0.2070
# Task: triple, Reward: -0.2810
# Task: triple, Reward: -0.1859
# Task: triple, Reward: -0.2715
# Task: triple, Reward: -0.3230
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.3093
# Task: triple, Reward: -0.2288
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2255
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.3012
# Task: triple, Reward: -0.2672
# Task: triple, Reward: -0.2592
# Task: triple, Reward: -0.2544
# Task: triple, Reward: -0.0921
# Task: triple, Reward: -0.2520
# Task: triple, Reward: -0.2865
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2346
# Task: triple, Reward: -0.2665
# Task: triple, Reward: -0.2805
# Task: triple, Reward: -0.2858
# Task: triple, Reward: -0.1808
# Task: triple, Reward: -0.2712
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.3134
# Task: triple, Reward: -0.1667
# Task: triple, Reward: -0.3440
# Task: triple, Reward: 0.0382
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2874
# Task: triple, Reward: -0.2182
# Task: triple, Reward: -0.2922
# Task: triple, Reward: -0.2458
# Task: triple, Reward: -0.2344
# Task: triple, Reward: -0.2415
# Task: triple, Reward: -0.2798
# Policy Loss: 2.6894
# Policy Loss: 2.4204
# Policy Loss: 2.4204
# Policy Loss: 2.4204
# Policy Loss: 2.4204
# Triple Value Loss: 0.0620
# Triple Episode 435/500
# Task: triple, Reward: -0.2381
# Task: triple, Reward: -0.1790
# Task: triple, Reward: -0.2253
# Task: triple, Reward: 0.0272
# Task: triple, Reward: -0.1963
# Task: triple, Reward: -0.2978
# Task: triple, Reward: -0.3052
# Task: triple, Reward: -0.2808
# Task: triple, Reward: -0.3044
# Task: triple, Reward: -0.2369
# Task: triple, Reward: -0.2596
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2253
# Task: triple, Reward: 0.0249
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2840
# Task: triple, Reward: -0.2609
# Task: triple, Reward: -0.2879
# Task: triple, Reward: -0.2955
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.3508
# Task: triple, Reward: -0.2581
# Task: triple, Reward: -0.2345
# Task: triple, Reward: -0.2061
# Task: triple, Reward: -0.2987
# Task: triple, Reward: -0.2858
# Task: triple, Reward: -0.3134
# Task: triple, Reward: -0.2064
# Task: triple, Reward: -0.3090
# Task: triple, Reward: -0.2623
# Task: triple, Reward: -0.2344
# Task: triple, Reward: -0.2520
# Task: triple, Reward: -0.3116
# Task: triple, Reward: -0.2214
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2579
# Task: triple, Reward: -0.1982
# Task: triple, Reward: -0.2465
# Task: triple, Reward: -0.2945
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2220
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2351
# Task: triple, Reward: -0.2880
# Task: triple, Reward: -0.2070
# Task: triple, Reward: -0.1778
# Task: triple, Reward: -0.3403
# Task: triple, Reward: -0.2267
# Policy Loss: 2.7540
# Policy Loss: 2.4786
# Policy Loss: 2.4786
# Policy Loss: 2.4786
# Policy Loss: 2.4786
# Triple Value Loss: 0.0600
# Triple Episode 436/500
# Task: triple, Reward: -0.2499
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2752
# Task: triple, Reward: -0.3563
# Task: triple, Reward: -0.2902
# Task: triple, Reward: -0.1639
# Task: triple, Reward: -0.2883
# Task: triple, Reward: -0.1945
# Task: triple, Reward: -0.2982
# Task: triple, Reward: -0.3026
# Task: triple, Reward: -0.2269
# Task: triple, Reward: 0.0433
# Task: triple, Reward: 0.0313
# Task: triple, Reward: -0.2135
# Task: triple, Reward: -0.2292
# Task: triple, Reward: 0.0143
# Task: triple, Reward: -0.2582
# Task: triple, Reward: -0.3126
# Task: triple, Reward: -0.2458
# Task: triple, Reward: -0.3331
# Task: triple, Reward: -0.2917
# Task: triple, Reward: -0.2276
# Task: triple, Reward: -0.2770
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2623
# Task: triple, Reward: -0.1649
# Task: triple, Reward: -0.1981
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2552
# Task: triple, Reward: -0.2155
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.3274
# Task: triple, Reward: -0.1418
# Task: triple, Reward: -0.1959
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.3373
# Task: triple, Reward: -0.2298
# Task: triple, Reward: -0.2281
# Task: triple, Reward: -0.2181
# Task: triple, Reward: -0.3528
# Task: triple, Reward: -0.3344
# Task: triple, Reward: -0.3051
# Task: triple, Reward: -0.2875
# Task: triple, Reward: -0.3205
# Task: triple, Reward: -0.2810
# Task: triple, Reward: -0.2439
# Task: triple, Reward: -0.2854
# Task: triple, Reward: -0.1885
# Policy Loss: 2.6867
# Policy Loss: 2.4213
# Policy Loss: 2.4180
# Policy Loss: 2.4180
# Policy Loss: 2.4180
# Triple Value Loss: 0.0633
# Triple Episode 437/500
# Task: triple, Reward: 0.0252
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2563
# Task: triple, Reward: -0.2490
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.2194
# Task: triple, Reward: -0.1791
# Task: triple, Reward: -0.2159
# Task: triple, Reward: -0.2346
# Task: triple, Reward: -0.2465
# Task: triple, Reward: -0.2368
# Task: triple, Reward: -0.3168
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.3100
# Task: triple, Reward: -0.2269
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.2317
# Task: triple, Reward: -0.3031
# Task: triple, Reward: -0.2381
# Task: triple, Reward: -0.2859
# Task: triple, Reward: -0.3115
# Task: triple, Reward: -0.1791
# Task: triple, Reward: -0.3144
# Task: triple, Reward: -0.2186
# Task: triple, Reward: -0.3333
# Task: triple, Reward: -0.3427
# Task: triple, Reward: -0.2071
# Task: triple, Reward: -0.2987
# Task: triple, Reward: -0.2639
# Task: triple, Reward: -0.2020
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2473
# Task: triple, Reward: -0.2253
# Task: triple, Reward: 0.0242
# Task: triple, Reward: -0.2119
# Task: triple, Reward: -0.2940
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.2363
# Task: triple, Reward: -0.2383
# Task: triple, Reward: -0.3056
# Task: triple, Reward: -0.2442
# Task: triple, Reward: -0.2219
# Task: triple, Reward: -0.2858
# Task: triple, Reward: -0.3051
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2110
# Policy Loss: 2.7296
# Policy Loss: 2.4566
# Policy Loss: 2.4566
# Policy Loss: 2.4566
# Policy Loss: 2.4566
# Triple Value Loss: 0.0601
# Triple Episode 438/500
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.2519
# Task: triple, Reward: -0.2249
# Task: triple, Reward: -0.2747
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.3290
# Task: triple, Reward: -0.2791
# Task: triple, Reward: -0.2634
# Task: triple, Reward: -0.2443
# Task: triple, Reward: 0.0232
# Task: triple, Reward: -0.2956
# Task: triple, Reward: -0.2623
# Task: triple, Reward: -0.1638
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.2984
# Task: triple, Reward: -0.2347
# Task: triple, Reward: -0.3403
# Task: triple, Reward: -0.2088
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2847
# Task: triple, Reward: -0.2215
# Task: triple, Reward: -0.2172
# Task: triple, Reward: -0.2706
# Task: triple, Reward: -0.2530
# Task: triple, Reward: -0.2552
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2817
# Task: triple, Reward: -0.2292
# Task: triple, Reward: 0.0306
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.2712
# Task: triple, Reward: -0.2269
# Task: triple, Reward: -0.2690
# Task: triple, Reward: -0.2562
# Task: triple, Reward: 0.0191
# Task: triple, Reward: -0.2219
# Task: triple, Reward: -0.1840
# Task: triple, Reward: -0.2513
# Task: triple, Reward: -0.2339
# Task: triple, Reward: -0.2402
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2737
# Task: triple, Reward: -0.2535
# Task: triple, Reward: -0.2601
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.2910
# Task: triple, Reward: -0.2369
# Task: triple, Reward: -0.2238
# Task: triple, Reward: -0.3273
# Task: triple, Reward: -0.3239
# Policy Loss: 2.5885
# Policy Loss: 2.3296
# Policy Loss: 2.3296
# Policy Loss: 2.3296
# Policy Loss: 2.3296
# Triple Value Loss: 0.0583
# Triple Episode 439/500
# Task: triple, Reward: -0.2133
# Task: triple, Reward: -0.1920
# Task: triple, Reward: -0.2864
# Task: triple, Reward: -0.1767
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.1878
# Task: triple, Reward: -0.2618
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2987
# Task: triple, Reward: -0.2146
# Task: triple, Reward: -0.2319
# Task: triple, Reward: -0.2816
# Task: triple, Reward: -0.2288
# Task: triple, Reward: -0.2048
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.3079
# Task: triple, Reward: -0.2754
# Task: triple, Reward: -0.3168
# Task: triple, Reward: -0.2365
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2504
# Task: triple, Reward: -0.2278
# Task: triple, Reward: -0.3142
# Task: triple, Reward: -0.3557
# Task: triple, Reward: 0.0313
# Task: triple, Reward: -0.2107
# Task: triple, Reward: -0.2326
# Task: triple, Reward: 0.0204
# Task: triple, Reward: -0.1674
# Task: triple, Reward: -0.2220
# Task: triple, Reward: -0.2484
# Task: triple, Reward: -0.2100
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2575
# Task: triple, Reward: -0.2823
# Task: triple, Reward: -0.2387
# Task: triple, Reward: -0.2146
# Task: triple, Reward: -0.1920
# Task: triple, Reward: -0.2279
# Task: triple, Reward: 0.0140
# Task: triple, Reward: -0.3315
# Task: triple, Reward: -0.2675
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2351
# Task: triple, Reward: -0.2256
# Task: triple, Reward: -0.3507
# Task: triple, Reward: -0.3257
# Task: triple, Reward: -0.2249
# Task: triple, Reward: -0.1840
# Policy Loss: 2.5461
# Policy Loss: 2.2927
# Policy Loss: 2.2915
# Policy Loss: 2.2915
# Policy Loss: 2.2915
# Triple Value Loss: 0.0564
# Triple Episode 440/500
# Task: triple, Reward: -0.3006
# Task: triple, Reward: -0.2651
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.3202
# Task: triple, Reward: -0.2800
# Task: triple, Reward: -0.2743
# Task: triple, Reward: -0.1912
# Task: triple, Reward: -0.2333
# Task: triple, Reward: -0.2181
# Task: triple, Reward: 0.0168
# Task: triple, Reward: -0.3208
# Task: triple, Reward: -0.2449
# Task: triple, Reward: -0.3129
# Task: triple, Reward: -0.3510
# Task: triple, Reward: -0.2081
# Task: triple, Reward: -0.2675
# Task: triple, Reward: -0.2377
# Task: triple, Reward: -0.3066
# Task: triple, Reward: -0.2450
# Task: triple, Reward: -0.2871
# Task: triple, Reward: -0.2764
# Task: triple, Reward: -0.2993
# Task: triple, Reward: -0.2760
# Task: triple, Reward: -0.2173
# Task: triple, Reward: -0.3456
# Task: triple, Reward: -0.1422
# Task: triple, Reward: 0.0154
# Task: triple, Reward: 0.0188
# Task: triple, Reward: -0.1420
# Task: triple, Reward: -0.3086
# Task: triple, Reward: -0.2573
# Task: triple, Reward: -0.2856
# Task: triple, Reward: -0.3321
# Task: triple, Reward: -0.2451
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.3173
# Task: triple, Reward: -0.2462
# Task: triple, Reward: -0.2678
# Task: triple, Reward: -0.2767
# Task: triple, Reward: -0.2368
# Task: triple, Reward: -0.2317
# Task: triple, Reward: -0.2899
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.1963
# Task: triple, Reward: -0.2638
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2349
# Task: triple, Reward: -0.1878
# Task: triple, Reward: -0.2370
# Task: triple, Reward: -0.2304
# Policy Loss: 2.6708
# Policy Loss: 2.4037
# Policy Loss: 2.4037
# Policy Loss: 2.4037
# Policy Loss: 2.4037
# Triple Value Loss: 0.0647
# Triple Episode 441/500
# Task: triple, Reward: -0.2033
# Task: triple, Reward: -0.2194
# Task: triple, Reward: -0.1776
# Task: triple, Reward: -0.2856
# Task: triple, Reward: -0.3501
# Task: triple, Reward: -0.2085
# Task: triple, Reward: -0.2635
# Task: triple, Reward: -0.2737
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.2163
# Task: triple, Reward: 0.0139
# Task: triple, Reward: -0.2309
# Task: triple, Reward: -0.2326
# Task: triple, Reward: -0.2477
# Task: triple, Reward: -0.2194
# Task: triple, Reward: -0.3053
# Task: triple, Reward: -0.2194
# Task: triple, Reward: -0.1790
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.2048
# Task: triple, Reward: -0.3091
# Task: triple, Reward: -0.2220
# Task: triple, Reward: -0.2204
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2685
# Task: triple, Reward: -0.2447
# Task: triple, Reward: -0.3087
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.3195
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.1667
# Task: triple, Reward: -0.2481
# Task: triple, Reward: -0.2457
# Task: triple, Reward: -0.2243
# Task: triple, Reward: -0.1791
# Task: triple, Reward: -0.2326
# Task: triple, Reward: -0.1963
# Task: triple, Reward: -0.1920
# Task: triple, Reward: -0.2821
# Task: triple, Reward: -0.2620
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.1420
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.2115
# Task: triple, Reward: -0.2139
# Task: triple, Reward: -0.2349
# Task: triple, Reward: -0.2181
# Task: triple, Reward: -0.2204
# ...
# Task: triple, Reward: -0.2173
# Task: triple, Reward: -0.2798
# Task: triple, Reward: -0.2996
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2587
# Task: triple, Reward: -0.1790
# Task: triple, Reward: -0.2370
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.2850
# Task: triple, Reward: -0.2209
# Task: triple, Reward: -0.2816
# Task: triple, Reward: -0.2215
# Task: triple, Reward: -0.2024
# Task: triple, Reward: -0.3230
# Task: triple, Reward: -0.2368
# Task: triple, Reward: -0.2048
# Task: triple, Reward: -0.2473
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2085
# Task: triple, Reward: -0.2544
# Task: triple, Reward: -0.2696
# Task: triple, Reward: -0.2823
# Task: triple, Reward: -0.2047
# Task: triple, Reward: 0.0814
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.1923
# Task: triple, Reward: -0.3158
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2547
# Task: triple, Reward: -0.2443
# Task: triple, Reward: -0.1981
# Task: triple, Reward: -0.2791
# Task: triple, Reward: -0.2393
# Policy Loss: 2.6172
# Policy Loss: 2.3555
# Policy Loss: 2.3555
# Policy Loss: 2.3555
# Policy Loss: 2.3555
# Triple Value Loss: 0.0594
# Triple Episode 492/500
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2948
# Task: triple, Reward: -0.2395
# Task: triple, Reward: -0.2380
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.2074
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2520
# Task: triple, Reward: -0.2219
# Task: triple, Reward: -0.2773
# Task: triple, Reward: -0.3479
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.3065
# Task: triple, Reward: -0.2507
# Task: triple, Reward: -0.3135
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2993
# Task: triple, Reward: -0.2638
# Task: triple, Reward: -0.2427
# Task: triple, Reward: -0.2607
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.1638
# Task: triple, Reward: -0.2552
# Task: triple, Reward: -0.1790
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2140
# Task: triple, Reward: -0.2557
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2293
# Task: triple, Reward: -0.2372
# Task: triple, Reward: -0.1649
# Task: triple, Reward: -0.2818
# Task: triple, Reward: -0.2573
# Task: triple, Reward: -0.1912
# Task: triple, Reward: -0.2799
# Task: triple, Reward: -0.2381
# Task: triple, Reward: -0.2686
# Task: triple, Reward: -0.1973
# Task: triple, Reward: -0.2589
# Task: triple, Reward: -0.3369
# Task: triple, Reward: -0.2694
# Task: triple, Reward: -0.2635
# Task: triple, Reward: -0.2195
# Task: triple, Reward: -0.2532
# Task: triple, Reward: -0.1941
# Task: triple, Reward: -0.2678
# Task: triple, Reward: -0.2767
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.3350
# Policy Loss: 2.7350
# Policy Loss: 2.4615
# Policy Loss: 2.4615
# Policy Loss: 2.4615
# Policy Loss: 2.4615
# Triple Value Loss: 0.0607
# Triple Episode 493/500
# Task: triple, Reward: 0.0202
# Task: triple, Reward: -0.3000
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.2430
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2173
# Task: triple, Reward: -0.2329
# Task: triple, Reward: -0.2822
# Task: triple, Reward: -0.2161
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.3296
# Task: triple, Reward: -0.2771
# Task: triple, Reward: -0.3057
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2172
# Task: triple, Reward: -0.1790
# Task: triple, Reward: -0.2659
# Task: triple, Reward: -0.1427
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.2194
# Task: triple, Reward: -0.2638
# Task: triple, Reward: -0.2933
# Task: triple, Reward: -0.2397
# Task: triple, Reward: -0.1963
# Task: triple, Reward: -0.2107
# Task: triple, Reward: -0.1908
# Task: triple, Reward: -0.2363
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.1717
# Task: triple, Reward: -0.2204
# Task: triple, Reward: -0.2768
# Task: triple, Reward: -0.2344
# Task: triple, Reward: -0.2172
# Task: triple, Reward: -0.2413
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2024
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2102
# Task: triple, Reward: -0.2204
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.3108
# Task: triple, Reward: -0.2858
# Task: triple, Reward: 0.1350
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2338
# Task: triple, Reward: -0.3050
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.1861
# Policy Loss: 2.4863
# Policy Loss: 2.2376
# Policy Loss: 2.2376
# Policy Loss: 2.2376
# Policy Loss: 2.2376
# Triple Value Loss: 0.0541
# Triple Episode 494/500
# Task: triple, Reward: -0.1774
# Task: triple, Reward: -0.2821
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.2413
# Task: triple, Reward: -0.2094
# Task: triple, Reward: -0.2913
# Task: triple, Reward: -0.2347
# Task: triple, Reward: -0.2155
# Task: triple, Reward: -0.3129
# Task: triple, Reward: -0.2537
# Task: triple, Reward: -0.1798
# Task: triple, Reward: -0.1639
# Task: triple, Reward: -0.2135
# Task: triple, Reward: -0.1717
# Task: triple, Reward: -0.3745
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.3102
# Task: triple, Reward: -0.1920
# Task: triple, Reward: -0.3480
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.1886
# Task: triple, Reward: -0.1639
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2950
# Task: triple, Reward: -0.2338
# Task: triple, Reward: -0.2083
# Task: triple, Reward: -0.2542
# Task: triple, Reward: -0.2675
# Task: triple, Reward: -0.2326
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2091
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2201
# Task: triple, Reward: -0.1775
# Task: triple, Reward: -0.2536
# Task: triple, Reward: 0.0259
# Task: triple, Reward: -0.2605
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2172
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.2108
# Task: triple, Reward: 0.0302
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.3250
# Task: triple, Reward: -0.3438
# Task: triple, Reward: -0.3094
# Task: triple, Reward: -0.2880
# Policy Loss: 2.5410
# Policy Loss: 2.2869
# Policy Loss: 2.2869
# Policy Loss: 2.2869
# Policy Loss: 2.2869
# Triple Value Loss: 0.0567
# Triple Episode 495/500
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2176
# Task: triple, Reward: -0.1963
# Task: triple, Reward: -0.2261
# Task: triple, Reward: -0.2910
# Task: triple, Reward: -0.2945
# Task: triple, Reward: -0.2146
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2768
# Task: triple, Reward: -0.2592
# Task: triple, Reward: -0.2107
# Task: triple, Reward: -0.2706
# Task: triple, Reward: -0.2767
# Task: triple, Reward: -0.2365
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.2999
# Task: triple, Reward: -0.3160
# Task: triple, Reward: 0.0171
# Task: triple, Reward: -0.2180
# Task: triple, Reward: -0.3212
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.3197
# Task: triple, Reward: -0.2478
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.2955
# Task: triple, Reward: -0.3382
# Task: triple, Reward: 0.0137
# Task: triple, Reward: -0.2579
# Task: triple, Reward: -0.2703
# Task: triple, Reward: -0.1920
# Task: triple, Reward: -0.1981
# Task: triple, Reward: -0.3187
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2650
# Task: triple, Reward: -0.3006
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.2984
# Task: triple, Reward: -0.2117
# Task: triple, Reward: -0.2298
# Task: triple, Reward: -0.2858
# Task: triple, Reward: -0.2315
# Task: triple, Reward: -0.3606
# Task: triple, Reward: -0.3019
# Task: triple, Reward: -0.2373
# Task: triple, Reward: -0.2549
# Task: triple, Reward: -0.2335
# Task: triple, Reward: -0.2624
# Task: triple, Reward: -0.3180
# Policy Loss: 2.8043
# Policy Loss: 2.5239
# Policy Loss: 2.5239
# Policy Loss: 2.5239
# Policy Loss: 2.5239
# Triple Value Loss: 0.0654
# Triple Episode 496/500
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2428
# Task: triple, Reward: -0.2523
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.1774
# Task: triple, Reward: -0.3053
# Task: triple, Reward: -0.3415
# Task: triple, Reward: -0.3641
# Task: triple, Reward: -0.2333
# Task: triple, Reward: -0.2437
# Task: triple, Reward: -0.2176
# Task: triple, Reward: -0.2602
# Task: triple, Reward: -0.3039
# Task: triple, Reward: -0.2231
# Task: triple, Reward: -0.2627
# Task: triple, Reward: -0.2762
# Task: triple, Reward: -0.2172
# Task: triple, Reward: -0.1982
# Task: triple, Reward: -0.1649
# Task: triple, Reward: -0.2070
# Task: triple, Reward: -0.2712
# Task: triple, Reward: -0.1923
# Task: triple, Reward: -0.2322
# Task: triple, Reward: -0.2064
# Task: triple, Reward: 0.0160
# Task: triple, Reward: -0.2218
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2070
# Task: triple, Reward: -0.1714
# Task: triple, Reward: -0.3085
# Task: triple, Reward: -0.2764
# Task: triple, Reward: -0.1584
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2204
# Task: triple, Reward: -0.2950
# Task: triple, Reward: -0.2630
# Task: triple, Reward: -0.2691
# Task: triple, Reward: -0.2220
# Task: triple, Reward: -0.2249
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.2085
# Task: triple, Reward: -0.2851
# Task: triple, Reward: -0.2232
# Task: triple, Reward: -0.2027
# Task: triple, Reward: -0.3335
# Task: triple, Reward: -0.2824
# Task: triple, Reward: -0.2220
# Task: triple, Reward: -0.2714
# Policy Loss: 2.6136
# Policy Loss: 2.3522
# Policy Loss: 2.3522
# Policy Loss: 2.3522
# Policy Loss: 2.3522
# Triple Value Loss: 0.0588
# Triple Episode 497/500
# Task: triple, Reward: 0.0144
# Task: triple, Reward: -0.2831
# Task: triple, Reward: -0.1821
# Task: triple, Reward: -0.2659
# Task: triple, Reward: -0.3604
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2557
# Task: triple, Reward: -0.3007
# Task: triple, Reward: -0.2372
# Task: triple, Reward: -0.2339
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2298
# Task: triple, Reward: -0.1638
# Task: triple, Reward: -0.2891
# Task: triple, Reward: -0.3029
# Task: triple, Reward: -0.3037
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.1849
# Task: triple, Reward: -0.3136
# Task: triple, Reward: -0.2889
# Task: triple, Reward: -0.2957
# Task: triple, Reward: -0.2024
# Task: triple, Reward: -0.2927
# Task: triple, Reward: -0.2439
# Task: triple, Reward: -0.2816
# Task: triple, Reward: -0.1694
# Task: triple, Reward: -0.2186
# Task: triple, Reward: -0.3470
# Task: triple, Reward: -0.1981
# Task: triple, Reward: -0.2339
# Task: triple, Reward: -0.2591
# Task: triple, Reward: 0.0169
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.3136
# Task: triple, Reward: -0.2245
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2428
# Task: triple, Reward: -0.2207
# Task: triple, Reward: -0.1988
# Task: triple, Reward: -0.1667
# Task: triple, Reward: 0.1433
# Task: triple, Reward: -0.3120
# Task: triple, Reward: -0.2852
# Task: triple, Reward: -0.2754
# Task: triple, Reward: -0.2301
# Task: triple, Reward: -0.3427
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.3743
# Task: triple, Reward: -0.3102
# Policy Loss: 2.6115
# Policy Loss: 2.3503
# Policy Loss: 2.3503
# Policy Loss: 2.3503
# Policy Loss: 2.3503
# Triple Value Loss: 0.0614
# Triple Episode 498/500
# Task: triple, Reward: -0.1767
# Task: triple, Reward: -0.1778
# Task: triple, Reward: -0.2302
# Task: triple, Reward: -0.3095
# Task: triple, Reward: -0.1812
# Task: triple, Reward: -0.2957
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.1639
# Task: triple, Reward: -0.1941
# Task: triple, Reward: -0.3018
# Task: triple, Reward: -0.2785
# Task: triple, Reward: -0.2947
# Task: triple, Reward: -0.2969
# Task: triple, Reward: -0.2290
# Task: triple, Reward: -0.2469
# Task: triple, Reward: -0.2182
# Task: triple, Reward: -0.1982
# Task: triple, Reward: -0.3084
# Task: triple, Reward: -0.2708
# Task: triple, Reward: -0.2970
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.2163
# Task: triple, Reward: -0.2292
# Task: triple, Reward: -0.2229
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2155
# Task: triple, Reward: -0.2179
# Task: triple, Reward: -0.1583
# Task: triple, Reward: -0.2122
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.3121
# Task: triple, Reward: -0.3213
# Task: triple, Reward: -0.2532
# Task: triple, Reward: -0.2982
# Task: triple, Reward: -0.2585
# Task: triple, Reward: -0.1876
# Task: triple, Reward: -0.2290
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.1859
# Task: triple, Reward: -0.2413
# Task: triple, Reward: -0.2424
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.3187
# Task: triple, Reward: -0.1714
# Task: triple, Reward: -0.2469
# Task: triple, Reward: -0.2957
# Task: triple, Reward: -0.2288
# Task: triple, Reward: -0.3006
# Task: triple, Reward: -0.2085
# Policy Loss: 2.6796
# Policy Loss: 2.4116
# Policy Loss: 2.4116
# Policy Loss: 2.4116
# Policy Loss: 2.4116
# Triple Value Loss: 0.0590
# Triple Episode 499/500
# Task: triple, Reward: -0.2346
# Task: triple, Reward: -0.2461
# Task: triple, Reward: -0.1944
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2267
# Task: triple, Reward: -0.3295
# Task: triple, Reward: -0.3060
# Task: triple, Reward: -0.1988
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.1569
# Task: triple, Reward: -0.2759
# Task: triple, Reward: -0.2403
# Task: triple, Reward: -0.2814
# Task: triple, Reward: 0.0175
# Task: triple, Reward: -0.1912
# Task: triple, Reward: -0.1767
# Task: triple, Reward: -0.2496
# Task: triple, Reward: 2.5100
# Task: triple, Reward: -0.3347
# Task: triple, Reward: -0.2194
# Task: triple, Reward: -0.2554
# Task: triple, Reward: -0.2843
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.2904
# Task: triple, Reward: -0.2381
# Task: triple, Reward: -0.2504
# Task: triple, Reward: -0.2956
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.3114
# Task: triple, Reward: -0.3184
# Task: triple, Reward: -0.3544
# Task: triple, Reward: -0.2428
# Task: triple, Reward: -0.2747
# Task: triple, Reward: -0.2123
# Task: triple, Reward: -0.2771
# Task: triple, Reward: -0.2956
# Task: triple, Reward: -0.2993
# Task: triple, Reward: -0.3360
# Task: triple, Reward: -0.2741
# Task: triple, Reward: -0.2299
# Task: triple, Reward: -0.2107
# Task: triple, Reward: -0.2651
# Task: triple, Reward: -0.3095
# Task: triple, Reward: -0.2536
# Task: triple, Reward: -0.2632
# Task: triple, Reward: -0.2888
# Task: triple, Reward: -0.2709
# Task: triple, Reward: -0.2339
# Task: triple, Reward: -0.2253
# Task: triple, Reward: -0.1773
# Policy Loss: 2.2615
# Policy Loss: 2.0354
# Policy Loss: 2.0354
# Policy Loss: 2.0354
# Policy Loss: 2.0354
# Triple Value Loss: 0.1915
# Triple Episode 500/500
# Task: triple, Reward: 0.0138
# Task: triple, Reward: -0.2912
# Task: triple, Reward: -0.2047
# Task: triple, Reward: -0.2461
# Task: triple, Reward: -0.1859
# Task: triple, Reward: -0.2993
# Task: triple, Reward: -0.2710
# Task: triple, Reward: -0.3339
# Task: triple, Reward: -0.1982
# Task: triple, Reward: -0.2303
# Task: triple, Reward: -0.1573
# Task: triple, Reward: -0.3501
# Task: triple, Reward: -0.1616
# Task: triple, Reward: -0.2281
# Task: triple, Reward: -0.2672
# Task: triple, Reward: -0.2733
# Task: triple, Reward: -0.2237
# Task: triple, Reward: -0.2510
# Task: triple, Reward: -0.2586
# Task: triple, Reward: -0.1923
# Task: triple, Reward: -0.1904
# Task: triple, Reward: -0.3347
# Task: triple, Reward: -0.2427
# Task: triple, Reward: -0.2110
# Task: triple, Reward: -0.2641
# Task: triple, Reward: -0.0933
# Task: triple, Reward: -0.3021
# Task: triple, Reward: -0.1638
# Task: triple, Reward: -0.3005
# Task: triple, Reward: -0.2807
# Task: triple, Reward: -0.2837
# Task: triple, Reward: -0.3044
# Task: triple, Reward: -0.2172
# Task: triple, Reward: -0.2397
# Task: triple, Reward: -0.3235
# Task: triple, Reward: -0.2436
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2537
# Task: triple, Reward: -0.2458
# Task: triple, Reward: -0.2310
# Task: triple, Reward: -0.2334
# Task: triple, Reward: -0.2588
# Task: triple, Reward: -0.3163
# Task: triple, Reward: -0.2181
# Task: triple, Reward: -0.1938
# Task: triple, Reward: -0.2433
# Task: triple, Reward: -0.2993
# Task: triple, Reward: -0.2999
# Task: triple, Reward: -0.2194
# Task: triple, Reward: -0.2253
# Policy Loss: 2.7796
# Policy Loss: 2.5016
# Policy Loss: 2.5016
# Policy Loss: 2.5016
# Policy Loss: 2.5016
# Triple Value Loss: 0.0620
# Saved RL fine-tuned DPR models for triple task.

# %%
# Save RL Metrics and Artifacts

# Save RL metrics
rl_metrics = {
    "qa_policy_losses": [],  # Placeholder for QA, as only triple task was re-run
    "qa_value_losses": [],   # Placeholder
    "triple_policy_losses": triple_policy_losses,
    "triple_value_losses": triple_value_losses
}

rl_metrics_path = os.path.join(CONFIG.BASE_PATH, "rl_metrics_v4.json")
with open(rl_metrics_path, "w") as f:
    json.dump(rl_metrics, f)
print(f"Saved RL metrics at {rl_metrics_path}")

# Save updated candidate embeddings
with torch.no_grad():
    # Limit candidate pool size for faster encoding
    eval_candidates = all_candidates[:1000]  # Limit to 1000 candidates
    candidate_inputs = ctx_tokenizer(eval_candidates, return_tensors="pt", padding=True, truncation=True, max_length=CONFIG.MAX_LENGTH)
    candidate_inputs = {k: v.to(CONFIG.DEVICE) for k, v in candidate_inputs.items()}
    candidate_embeddings_qa = ctx_encoder_qa(**candidate_inputs).pooler_output
    candidate_embeddings_triple = ctx_encoder_triple(**candidate_inputs).pooler_output
torch.save(candidate_embeddings_qa, os.path.join(save_path, 'dpr_candidate_embeddings_rl_qa_v4.pt'))
torch.save(candidate_embeddings_triple, os.path.join(save_path, 'dpr_candidate_embeddings_rl_triple_v4.pt'))

print("Updated candidate embeddings saved for Version 4.")
# Out:
# Saved RL metrics at /content/drive/MyDrive/LJMU-Datasets/rl_metrics_v4.json
# Updated candidate embeddings saved for Version 4.
